# %%
# %load_ext autoreload
# %autoreload 2
# !pwd
import os
import sys 
if os.path.abspath("../../../") not in sys.path:
    print(os.path.abspath("../../../../"))
    sys.path.append(os.path.abspath("../../../")) 

import os
import networkx as nx
from rwtools.nemesis.graph.nemesis_node import AbstractNemesisNode
import matplotlib.pyplot as plt
import os
import matplotlib.image as mpimg
from rwtools.nemesis.control_flow_graph import ControlFlowGraph
# Out:
# /home/gilles/git-repos/NemesisRetroWrite/retrowrite/rwtools/nemesis/samples_notebooks
# /home/gilles/git-repos/NemesisRetroWrite

# %%
import sys 
sys.executable
# Out:
# '/home/gilles/git-repos/NemesisRetroWrite/retrowrite/venv/bin/python'

# %%
from test_main import setup 
from rwtools.nemesis.nemesistool import NemesisInstrument 



binary = os.path.abspath("./simple/simple")
outputfile = "./test.s"

nemesis = NemesisInstrument(binary, outputfile)

nemesis.dump()
figs, axs = plt.subplots(1, figsize=(10,10))

axs.imshow(nemesis.render_cfg())
# Out:
# [*] Relocations for a section that's not loaded: .rela.dyn
# [x] Could not replace value in .init_array
# [x] Couldn't find valid section 3e20
# [x] Couldn't find valid section 3fd8
# [x] Couldn't find valid section 3fe0
# [x] Couldn't find valid section 3fe8
# [x] Couldn't find valid section 3ff0
# [x] Couldn't find valid section 3ff8

# %%
figs, axs = plt.subplots(1, figsize=(10,10))
nemesis.instrument()
nemesis.align()
axs.imshow(nemesis.render_cfg())

# %%
figs, axs = plt.subplots(1, figsize=(10,10))
nemesis.instrument()
nemesis.align()
axs.imshow(nemesis.render_cfg())

# %%
# figs, axs = plt.subplots(1, figsize=(20,20))

# binary = os.path.abspath("./password_comparison/password_comparison")
# outputfile = "./test.s"

# nemesis = NemesisInstrument(binary, outputfile)
# nemesis.instrument()

# nemesis.align()

# nemesis.finalize()

# axs.imshow(nemesis.render_cfg())



# nemesis.dump()

# %% [markdown]
# # Try inserting push and pop without adding other instructions -- this should work
#
# This does in fact work

# %%
binary = os.path.abspath("./password_comparison/password_comparison")
outputfile = "./test.s"

nemesis = NemesisInstrument(binary, outputfile)

figs, axs = plt.subplots(1, figsize=(20,20))


root = nemesis.cfg.get_root()
leaves = nemesis.cfg.get_leaves()
reg = "r8"

root.insert(0, f"pushq %{reg}", 1)

for leaf in leaves:
    n = leaf.num_instructions()

    leaf.insert(n-1, f"popq %{reg}", 1)
    
axs.imshow(nemesis.render_cfg())

nemesis.dump()
# Out:
# [*] Relocations for a section that's not loaded: .rela.dyn
# [x] Could not replace value in .init_array
# [x] Couldn't find valid section 3e20
# [x] Couldn't find valid section 3fd8
# [x] Couldn't find valid section 3fe0
# [x] Couldn't find valid section 3fe8
# [x] Couldn't find valid section 3ff0
# [x] Couldn't find valid section 3ff8

# %%
figs, axs = plt.subplots(1, figsize=(20,20))

binary = os.path.abspath("./password_comparison/password_comparison")
outputfile = "./test_rw.s"

nemesis = NemesisInstrument(binary, outputfile)


# unwind, insert nodes, equalize branches 
nemesis.instrument()

target_node = nemesis.cfg.get_node('1169')


nemesis.align(target_node)

# nemesis.finalize()
    
axs.imshow(nemesis.render_cfg())

# nemesis.dump()
# Out:
# [*] Relocations for a section that's not loaded: .rela.dyn
# [x] Could not replace value in .init_array
# [x] Couldn't find valid section 3e20
# [x] Couldn't find valid section 3fd8
# [x] Couldn't find valid section 3fe0
# [x] Couldn't find valid section 3fe8
# [x] Couldn't find valid section 3ff0
# [x] Couldn't find valid section 3ff8
# ['1169', '118d', '1169118d', '1184']

# %% [markdown]
# # Rules for inserting istructions
# Don't

# %%
figs, axs = plt.subplots(1, figsize=(20,20))

binary = os.path.abspath("./a.out")
outputfile = "./dump.s"

nemesis = NemesisInstrument(binary, outputfile)

# nemesis.instrument()

# nemesis.align()

# nemesis.finalize()
    
axs.imshow(nemesis.render_cfg())

# nemesis.dump()
# Out:
# [*] Relocations for a section that's not loaded: .rela.dyn
# [x] Could not replace value in .init_array
# [x] Couldn't find valid section 3df8
# [x] Couldn't find valid section 3fd8
# [x] Couldn't find valid section 3fe0
# [x] Couldn't find valid section 3fe8
# [x] Couldn't find valid section 3ff0
# [x] Couldn't find valid section 3ff8
