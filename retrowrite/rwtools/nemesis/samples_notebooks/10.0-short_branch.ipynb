# %%
# %load_ext autoreload
# %autoreload 2
# !pwd
import os
import sys 
if os.path.abspath("../../../") not in sys.path:
    sys.path.append(os.path.abspath("../../../")) 

import os
import networkx as nx
from rwtools.nemesis.graph.nemesis_node import AbstractNemesisNode
import matplotlib.pyplot as plt
import os
import matplotlib.image as mpimg
from rwtools.nemesis.control_flow_graph import ControlFlowGraph
# Out:
# /home/gilles/git-repos/NemesisRetroWrite/retrowrite/rwtools/nemesis/samples_notebooks

# %% [markdown]
# # Example of complete workflow with a very simple piece of code
# `simple/simple.c`
#
# ```
# int main(){
# 	int secret = 1;
# 	if (secret < 10){
# 		return 0;
# 	} else{
# 		return 1;
# 	}
# }
# ```

# %%
from test_main import setup 

binary = os.path.abspath("./short_branch/short_branch")
outputfile = "./short_branch_rw.s"
loader, rw = setup(binary, outputfile)
rw.dump()
# Out:
# [*] Relocations for a section that's not loaded: .rela.dyn
# [x] Could not replace value in .init_array
# [x] Couldn't find valid section 3e20
# [x] Couldn't find valid section 3fd8
# [x] Couldn't find valid section 3fe0
# [x] Couldn't find valid section 3fe8
# [x] Couldn't find valid section 3ff0
# [x] Couldn't find valid section 3ff8

# %%
from rwtools.nemesis.graph.utils import create_graph_structure
from rwtools.nemesis.graph.utils import to_img
from rwtools.nemesis.graph.balance import balance_branching_point


outputfile = "./short_branch/short_branch.s"
loader, rw = setup(binary, outputfile)
function_names = loader.container.function_names
nodes, graph = create_graph_structure(loader.container, "main")
fig, axs = plt.subplots(2, figsize=(30, 30))


control_flow_graph = ControlFlowGraph(nodes=nodes, graph=graph)

control_flow_graph.merge_consecutive_nodes()
# axs[0].imshow(to_img(graph))

# control_flow_graph.unwind_graph()

control_flow_graph.insert_nodes()
axs[0].imshow(to_img(graph))
target_node = control_flow_graph.get_node('1130')

control_flow_graph.set_stopping_nodes(target_node)
balance_branching_point(control_flow_graph, target_node)

# control_flow_graph.merge_inserted_nodes()

axs[1].imshow(to_img(graph))

rw.dump()
# Out:
# [*] Relocations for a section that's not loaded: .rela.dyn
# [x] Could not replace value in .init_array
# [x] Couldn't find valid section 3e20
# [x] Couldn't find valid section 3fd8
# [x] Couldn't find valid section 3fe0
# [x] Couldn't find valid section 3fe8
# [x] Couldn't find valid section 3ff0
# [x] Couldn't find valid section 3ff8
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-3b954bbdfbe6> in <module>
#      23
#      24 control_flow_graph.set_stopping_nodes(target_node)
# ---> 25 balance_branching_point(control_flow_graph, target_node)
#      26
#      27 # control_flow_graph.merge_inserted_nodes()
#
# ~/git-repos/NemesisRetroWrite/retrowrite/rwtools/nemesis/graph/balance.py in balance_branching_point(cfg, node)
#      28     elif True not in nodes_are_leaves:
#      29         # both nodes are trees if all values are false <=> no value are true
# ---> 30         balance_tree_latencies(cfg, child1, child2)
#      31     else:
#      32         if nodes_are_leaves[0]:
#
# ~/git-repos/NemesisRetroWrite/retrowrite/rwtools/nemesis/graph/balance.py in balance_tree_latencies(cfg, tree1, tree2)
#      99
#     100     # then balance the subtrees independentely from one another
# --> 101     balance_branching_point(cfg, tree1)
#     102     balance_branching_point(cfg, tree2)
#     103
#
# ~/git-repos/NemesisRetroWrite/retrowrite/rwtools/nemesis/graph/balance.py in balance_branching_point(cfg, node)
#      28     elif True not in nodes_are_leaves:
#      29         # both nodes are trees if all values are false <=> no value are true
# ---> 30         balance_tree_latencies(cfg, child1, child2)
#      31     else:
#      32         if nodes_are_leaves[0]:
#
# ~/git-repos/NemesisRetroWrite/retrowrite/rwtools/nemesis/graph/balance.py in balance_tree_latencies(cfg, tree1, tree2)
#      96 def balance_tree_latencies(cfg, tree1, tree2):
#      97     # First balance the roots
# ---> 98     balance_node_latencies(tree1, tree2)
#      99
#     100     # then balance the subtrees independentely from one another
#
# ~/git-repos/NemesisRetroWrite/retrowrite/rwtools/nemesis/graph/balance.py in balance_node_latencies(n1, n2)
#      49     n1.replace_instructions(new_instructions_n1)
#      50
# ---> 51     new_instructions_n2 = create_new_instruction_sequence(instructions=n2.get_instructions_with_latencies(),
#      52                                                           target_latencies=balanced_latencies)
#      53     n2.replace_instructions(new_instructions_n2)
#
# ~/git-repos/NemesisRetroWrite/retrowrite/rwtools/nemesis/latency_balancing.py in create_new_instruction_sequence(instructions, target_latencies)
#     147     for latency_sequence, index in missing_latencies:
#     148         # map the latency sequence to a sequence of actual instructions
# --> 149         instructions = map_latency_sequence_to_instructions(latency_sequence)
#     150         instructions = list(zip(instructions, latency_sequence))
#     151
#
# ~/git-repos/NemesisRetroWrite/retrowrite/rwtools/nemesis/nop_instructions.py in map_latency_sequence_to_instructions(latency_sequence)
#      68                 "add $0x8, %rsp"]
#      69     else:
# ---> 70         raise ValueError(f"Don't know what to do for latency sequence {latency_sequence}")
#
# ValueError: Don't know what to do for latency sequence [3, 3, 3, 3, 3, 1, 3, 3, 3, 3, 3]

# %%
rw.dump()
rw.outfile

# with open(outputfile, "r") as f: 
#     content = f.read() 
#     print(content)
# Out:
# './simple_rw.s'
