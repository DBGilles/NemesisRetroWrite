# %%
# %load_ext autoreload
# %autoreload 2
# !pwd
import os
import sys 
if os.path.abspath("../../../") not in sys.path:
    sys.path.append(os.path.abspath("../../../")) 

import os
# import networkx as nx
from rwtools.nemesis.latency_map.create_latency_map import *
from rwtools.nemesis.graph.nemesis_node import AbstractNemesisNode
import matplotlib.pyplot as plt
import os
import matplotlib.image as mpimg
from rwtools.nemesis.graph.control_flow_graph import ControlFlowGraph
# Out:
# /home/gilles/git-repos/NemesisRetroWrite/retrowrite/rwtools/nemesis/evaluation_notebooks

# %% [markdown]
# # Load list of branching instructions
# In the form of instruction addresses

# %%
import json 

test_name = "kruskal"

input_binary = os.path.abspath(f"../test_programs/{test_name}/{test_name}")
output_assembly = os.path.abspath(f"../test_programs/{test_name}/{test_name}_rw.s")
output_binary = os.path.abspath(f"../test_programs/{test_name}/{test_name}_rw")
test_values = os.path.abspath(f"../test_programs/{test_name}/test_inputs.txt")

# %% [markdown]
# # instrument each function seperately
# First instrument the code, then dump the rewritten program, then compile into new binary using gcc

# %%
from rwtools.nemesis.nemesistool import NemesisInstrumentProgram
import subprocess 

tool = NemesisInstrumentProgram(input_binary, output_assembly)

func = tool.functions['kruskal']

figs, axs = plt.subplots(1, figsize=(20,20))

axs.imshow(func.render_cfg())
# Out:
# [*] Relocations for a section that's not loaded: .rela.dyn
# [*] Relocations for a section that's not loaded: .rela.plt
# [x] Could not replace value in .init_array
# [x] Couldn't find valid section 3df0
# [x] Couldn't find valid section 3fd8
# [x] Couldn't find valid section 3fe0
# [x] Couldn't find valid section 3fe8
# [x] Couldn't find valid section 3ff0
# [x] Couldn't find valid section 3ff8
# unknown type: .LC2050(%rip), %xmm0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/git-repos/NemesisRetroWrite/retrowrite/rwtools/nemesis/latency_map/latency_map.py in get_latency(self, *args)
#     214         try:
# --> 215             operands = split_operands(args[1]) if len(args) > 1 else []
#     216         except ValueError:
#
# ~/git-repos/NemesisRetroWrite/retrowrite/rwtools/nemesis/latency_map/latency_map.py in split_operands(op_string)
#      71         print("unknown type:", op_string)
# ---> 72         raise ValueError(f"unkown type {op_string}")
#      73
#
# ValueError: unkown type .LC2050(%rip), %xmm0
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-74beba1eb308> in <module>
#       2 import subprocess
#       3
# ----> 4 tool = NemesisInstrumentProgram(input_binary, output_assembly)
#       5
#       6 func = tool.functions['kruskal']
#
# ~/git-repos/NemesisRetroWrite/retrowrite/rwtools/nemesis/nemesistool.py in __init__(self, binary, outputfile)
#     120                                value['name'] not in GCC_FUNCTIONS]
#     121         for fn in self.function_names:
# --> 122             function_instrumenter = NemesisInstrumentFunction(self.loader, fn)
#     123             self.functions[fn] = function_instrumenter
#     124
#
# ~/git-repos/NemesisRetroWrite/retrowrite/rwtools/nemesis/nemesistool.py in __init__(self, loader, target_function)
#     147             "/home/gilles/git-repos/NemesisRetroWrite/retrowrite/rwtools/nemesis/latency_map"
#     148             "/latencies.p"))
# --> 149         self._setup()
#     150
#     151     def _setup(self):
#
# ~/git-repos/NemesisRetroWrite/retrowrite/rwtools/nemesis/nemesistool.py in _setup(self)
#     151     def _setup(self):
#     152         # create control flow graph
# --> 153         self.create_cfg()
#     154
#     155         # do analysis
#
# ~/git-repos/NemesisRetroWrite/retrowrite/rwtools/nemesis/nemesistool.py in create_cfg(self)
#     176         for instr in target_fn.cache:
#     177             # instr is an instance of class librw.container.InstructionWrapper
# --> 178             instr_latency = self.latency_mapper.get_latency(instr.mnemonic, instr.op_str)
#     179             nodes.append(NemesisNode(instr, instr_latency))
#     180             # nodes[fn.name].append(NemesisNode(instr))
#
# ~/git-repos/NemesisRetroWrite/retrowrite/rwtools/nemesis/latency_map/latency_map.py in get_latency(self, *args)
#     215             operands = split_operands(args[1]) if len(args) > 1 else []
#     216         except ValueError:
# --> 217             raise ValueError(f"error on spliting operands for instruction {instruction}")
#     218
#     219         candidates = self.get_candidates(instruction)
#
# ValueError: error on spliting operands for instruction movaps

# %%
from rwtools.nemesis.nemesistool import NemesisInstrumentProgram
import subprocess 

tool = NemesisInstrumentProgram(input_binary, output_assembly)
tool.instrument_program(['11e8'])

func = tool.functions['kruskal']

figs, axs = plt.subplots(1, figsize=(20,20))

axs.imshow(func.render_cfg())
tool.dump() 
subprocess.run(["gcc", output_assembly, "-o", output_binary])
# Out:
# [*] Relocations for a section that's not loaded: .rela.dyn
# [*] Relocations for a section that's not loaded: .rela.plt
# [x] Could not replace value in .init_array
# [x] Couldn't find valid section 3df0
# [x] Couldn't find valid section 3fd8
# [x] Couldn't find valid section 3fe0
# [x] Couldn't find valid section 3fe8
# [x] Couldn't find valid section 3ff0
# [x] Couldn't find valid section 3ff8
# find
# kruskal
# main
# CompletedProcess(args=['gcc', '/home/gilles/git-repos/NemesisRetroWrite/retrowrite/rwtools/nemesis/test_programs/kruskal/kruskal_rw.s', '-o', '/home/gilles/git-repos/NemesisRetroWrite/retrowrite/rwtools/nemesis/test_programs/kruskal/kruskal_rw'], returncode=0)

# %%
from rwtools.nemesis.evaluationtool import NemesisEvaluateProgram 
evaluation = NemesisEvaluateProgram(output_binary, "")

figs, axs = plt.subplots(1, figsize=(20,20))

evaluation.evaluate_program(['11e3'])
axs.imshow(evaluation.functions['kruskal'].render_cfg())
# Out:
# [*] Relocations for a section that's not loaded: .rela.dyn
# [*] Relocations for a section that's not loaded: .rela.plt
# [x] Could not replace value in .init_array
# [x] Couldn't find valid section 3dc0
# [x] Couldn't find valid section 3fd8
# [x] Couldn't find valid section 3fe0
# [x] Couldn't find valid section 3fe8
# [x] Couldn't find valid section 3ff0
# [x] Couldn't find valid section 3ff8
# no issues found

# %%
test_cases = []

with open(test_values, "r") as f: 
    for line in f:
        test_cases.append(line.strip().split(" "))

for test_case in test_cases: 
    expected = subprocess.run([input_binary, *test_case]).returncode
    result = subprocess.run([output_binary, *test_case]).returncode
    if expected != result:
        print("incorrect result on test with inputs", *test_case)
    else: 
        print("correct")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-312f47ac75a9> in <module>
#       1 test_cases = []
#       2
# ----> 3 with open(test_values, "r") as f:
#       4     for line in f:
#       5         test_cases.append(line.strip().split(" "))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/gilles/git-repos/NemesisRetroWrite/retrowrite/rwtools/nemesis/test_programs/kruskal/test_inputs.txt'
