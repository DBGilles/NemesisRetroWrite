# %%
import opcodes

# %%
from opcodes.x86_64 import read_instruction_set
instruction_set = read_instruction_set()  # set of Instruction instances 

# create an dictionary containing initial default value for latency 
latency_dict = dict() 
for instr in instruction_set: 
    for form in instr.forms: 
        # instances of InstructionForm -- forms mainly differen by operands 
        name = form.name  # base mnemonic (i think) 
        gas_name = form.gas_name  # name with possible modifiers (I think) 
        operands = [op.type for op in form.operands]
        entry_key = (name,gas_name ) + tuple(operands)
        latency_dict[entry_key] = 1

# %%
import os
import pandas as pd

data_dir = os.path.abspath("../data1/")
ods_file = os.path.join(data_dir, "skylave_extracted.ods")
raw_data = pd.read_excel(ods_file, engine="odf")

latency_data = raw_data[['instruction', 'operands', 'latency']]
latency_data = latency_data.drop(latency_data[latency_data.instruction.isnull()].index)

# iterate over rows 
latency = None 

def convert_latency(lat):
    """
    Convert the given latency to a fixed type (float) -- ensure uniformity between rows 
    """
    if isinstance(lat, int):
        return lat
    elif isinstance(lat, float): 
        return int(lat)
    elif isinstance(lat, str):
        try: 
            # try casting string to float and returning it 
            return int(lat)
        except ValueError: 
            # if it doesn succeed, continue with rest of the function z
            pass 
        # several special cases, handle seperately 
        if "-" in lat: 
            # latency of type 'a-b' -- return float(b) 
            return int(lat.split("-")[-1])
        if 'b' in lat: 
            return -1 
        if "~" in lat: 
            return int(lat[1:])

### Step 1 : Ensure every row has a valid latency value ### 
for index, row in latency_data.iterrows():
    if row.isnull().latency == False:
        converted_latency = convert_latency(row.latency)  # convert latency to a float
        assert isinstance(converted_latency, int)
        row.latency = converted_latency # store this converted value
        latency = converted_latency # store locally as wel
    else:
        row.latency = latency

print("NaN values in latency: ", latency_data.latency.isnull().any())
latency_data.head(20)
# Out:
# NaN values in latency:  False
#            instruction       operands latency
# 2                  MOV            r,i       1
# 3                  MOV    r8/16,r8/16       1
# 4                  MOV  r32/64,r32/64       1
# 5                  MOV          r8l,m       1
# 6                  MOV          r8h,m       1
# 7                  MOV          r16,m       1
# 8                  MOV       r32/64,m       2
# 9                  MOV            m,r       2
# 10                 MOV            m,i       2
# 11              MOVNTI            m,r     400
# 12  MOVSX MOVZX MOVSXD            r,r       1
# 13         MOVSX MOVZX         r16,m8       1
# 14  MOVSX MOVZX MOVSXD            r,m       1
# 15              CMOVcc            r,r       1
# 16              CMOVcc            r,m       1
# 17                XCHG            r,r       2
# 18                XCHG            r,m      23
# 19                XLAT            NaN       7
# 20                PUSH              r       3
# 21                PUSH              i       3

# %%
### Step 2 : Split up rows that contain multiple instructions seperated by spaces ### 
latency_data_cpy = latency_data.copy(deep=True)

multi_instructions = latency_data_cpy['instruction'].str.contains(" ")

target_rows_index = latency_data_cpy[multi_instructions].index

new_rows = []

for i in target_rows_index: 
    row = latency_data_cpy.loc[i]
    operands = row['operands']
    latency = row['latency']
    names = list(filter(lambda x : len(x) > 0, row['instruction'].split(" ")))
    
    # create new rows, one for each seperate name 
    new_rows += [[n, operands, latency] for n in names] 

# create a dataframe that contains the new rows 
new_data = pd.DataFrame(new_rows, columns = latency_data_cpy.columns)

# delete the rows that have just been split up from the original dataframe
latency_data_cpy.drop(target_rows_index, inplace=True)

# finally, append/concatenate the dataframe containing the newly created rows 
processed_latency = pd.concat([latency_data_cpy, new_data])
processed_latency.reset_index(drop=True)
processed_latency.loc[processed_latency['instruction'].str.contains("SUB")]
processed_latency.head(10)
# Out:
#    instruction       operands latency
# 2          MOV            r,i       1
# 3          MOV    r8/16,r8/16       1
# 4          MOV  r32/64,r32/64       1
# 5          MOV          r8l,m       1
# 6          MOV          r8h,m       1
# 7          MOV          r16,m       1
# 8          MOV       r32/64,m       2
# 9          MOV            m,r       2
# 10         MOV            m,i       2
# 11      MOVNTI            m,r     400

# %%
"""
From the instructions documen : 
Operands can be different types of registers, memory, or immediate constants. Ab-
breviations used in the tables are: i = immediate constant, r = any general purpose
register, r32 = 32-bit register, etc., mm = 64 bit mmx register, x or xmm = 128 bit xmm
register, y = 256 bit ymm register, z = 512 bit zmm register, v = any vector register, sr
= segment register, m = any memory operand including indirect operands, m64
means 64-bit memory operand, etc
"""
register_names = ["r"] + [f"r{x}" for x in [8, 16, 32, 64, 128, 256]] + [f"{x}mm" for x in ["", "x", "y", "z"]]
register_names += ["x", "y", "z"]
register_names += ["v", "sr"]
register_names += ['r8l', 'r8h']
register_names += ['AX', 'ax']

memory_operands = [f"m{x}" for x in ['', 8, 16, 32, 64, 128, 256, 512]]

immediate_operands = ["i"]

all_types = register_names + memory_operands + immediate_operands

def is_type(a): 
    return a in all_types 

def is_reg(a):
    if isinstance(a, opcodes.x86_64.Operand):
        return a.is_register
    else: 
        return a in register_names

def is_mem(a):
    if isinstance(a, opcodes.x86_64.Operand):
        return a.is_memory
    else: 
        return a in memory_operands

def is_imm(a):
    if isinstance(a, opcodes.x86_64.Operand):
        return a.is_immediate
    else: 
        return a in immediate_operands

def type_match(a, b): 
    if is_reg(a) and is_reg(b):
        return True 
    elif is_mem(a) and is_mem(b): 
        return True 
    elif is_imm(a) and is_imm(b): 
        return True 
    else: 
        return False

# %%
latency_dict_operands = processed_latency['operands']

def cast_to_types(op_types):
    if not False in map(lambda x : is_type(x), op_types): 
        return op_types
    # first, determine if this is some special case 
    if '[' in op_types[0] and ']' in op_types[0]: 
        # 'r+s*y' (represents some compound type maybe? IDK?)
        return []
    elif 'stack pointer' in op_types[0]: 
        # TODO: check if stack pointer needs its own type 
        return ['m'] 
    elif 'cl' in op_types[0]: 
        # no clue what this could be 
        return []
    elif 'short' in op_types[0] or 'near' in op_types[0]:
        # TODO check if distinction between short and near is important for latency 
        return ['m'] 
    elif 'a' in op_types[0] or 'b' in op_types[0]:        
        return ['i16'] # use only in enter (and somehwere else, idk) https://www.felixcloutier.com/x86/enter
    elif '0' in op_types[0] or '1' in op_types[0]: 
        return ['i16'] # TODO nakijken 
    elif len(op_types) == 2 and is_type(op_types[0]):
        # cast second op type to type of first -- 
        # at this point you can simply preprend first char to get crrect type 
        return [op_types[0], op_types[0][0] + op_types[1]] 
    

def extract_operand_types(op_string):
    """
    Return for each operand position (seperated by commas) a list of possible operand typess 
    eg input 'r32/64,r32/64' return [r32, r64], [r32, r64] 
    """

    if op_string == "nan" or op_string is None or isinstance(op_string, float):
        # nan is apparently of type float 
        return [] 
    
    operand_positions = op_string.split(",")
    operand_types = []
    for ops in operand_positions:
        # now we are looking at individual operands -- ensure they are one of the types defined above, if not cast 
        op_types = list(map(lambda x : x.strip(), ops.split("/")))
        operand_types.append(cast_to_types(op_types))
    return operand_types

# %%
# for each value in the dicationary, query the latency data


def length_diff(a, b): 
    return abs(len(a) - len(b))

def best_candidate(k, candidates): 
    # get the candidate that is the best/closest match to key k (in terms of name, operands, etc)
    if len(candidates) == 1: 
        return candidates.iloc[0]
    else: 
        # sort candidates based on length similarity 
        target_name, target_gas_name = key[:2]
        operands = key[2:] if len(key) > 2 else []         
        candidates = candidates.values.tolist() 
        candidates.sort(key=lambda x: length_diff(x[0], key[0]))
        
        candidate_match_counts = []
        for c in candidates: 
            candidate_ops = c[1]
            candidate_op_types = extract_operand_types(candidate_ops)
            match_count = 0 
            for op, candidate_types in zip(operands, candidate_op_types): 
                op = opcodes.x86_64.Operand(op)
                for c in candidate_types:
                    if type_match(op, c):
                        match_count += 1 
                        break 
            candidate_match_counts.append(match_count) 
        max_i = candidate_match_counts.index(max(candidate_match_counts))
        return candidates[max_i]    
        
for key, value in latency_dict.items():
    name = key[0]  # get the instruction name
    gas_name = key[1]
    #  find all rows that potentially contain this instruction 
    candidates = processed_latency[processed_latency['instruction'].str.contains(name, case=False)] 
    if len(candidates) == 0: 
        continue 
    # find the best match among these candidates 
    best = best_candidate(key, candidates) 
    best_latency = best[-1]
    latency_dict[key] = best_latency

# %%
latency_dict
# Out:
# {('ADC', 'adcb', 'al', 'imm8'): 1,
#  ('ADC', 'adcb', 'r8', 'imm8'): 1,
#  ('ADC', 'adcb', 'r8', 'r8'): 1,
#  ('ADC', 'adcb', 'r8', 'm8'): 1,
#  ('ADC', 'adcw', 'ax', 'imm16'): 1,
#  ('ADC', 'adcw', 'r16', 'imm8'): 1,
#  ('ADC', 'adcw', 'r16', 'imm16'): 1,
#  ('ADC', 'adcw', 'r16', 'r16'): 1,
#  ('ADC', 'adcw', 'r16', 'm16'): 1,
#  ('ADC', 'adcl', 'eax', 'imm32'): 1,
#  ('ADC', 'adcl', 'r32', 'imm8'): 1,
#  ('ADC', 'adcl', 'r32', 'imm32'): 1,
#  ('ADC', 'adcl', 'r32', 'r32'): 1,
#  ('ADC', 'adcl', 'r32', 'm32'): 1,
#  ('ADC', 'adcq', 'rax', 'imm32'): 1,
#  ('ADC', 'adcq', 'r64', 'imm8'): 1,
#  ('ADC', 'adcq', 'r64', 'imm32'): 1,
#  ('ADC', 'adcq', 'r64', 'r64'): 1,
#  ('ADC', 'adcq', 'r64', 'm64'): 1,
#  ('ADC', 'adcb', 'm8', 'imm8'): 5,
#  ('ADC', 'adcb', 'm8', 'r8'): 5,
#  ('ADC', 'adcw', 'm16', 'imm8'): 5,
#  ('ADC', 'adcw', 'm16', 'imm16'): 5,
#  ('ADC', 'adcw', 'm16', 'r16'): 5,
#  ('ADC', 'adcl', 'm32', 'imm8'): 5,
#  ('ADC', 'adcl', 'm32', 'imm32'): 5,
#  ('ADC', 'adcl', 'm32', 'r32'): 5,
#  ('ADC', 'adcq', 'm64', 'imm8'): 5,
#  ('ADC', 'adcq', 'm64', 'imm32'): 5,
#  ('ADC', 'adcq', 'm64', 'r64'): 5,
#  ('ADCX', 'adcxl', 'r32', 'r32'): 1,
#  ('ADCX', 'adcxl', 'r32', 'm32'): 1,
#  ('ADCX', 'adcxq', 'r64', 'r64'): 1,
#  ('ADCX', 'adcxq', 'r64', 'm64'): 1,
#  ('ADD', 'addb', 'al', 'imm8'): 1,
#  ('ADD', 'addb', 'r8', 'imm8'): 1,
#  ('ADD', 'addb', 'r8', 'r8'): 1,
#  ('ADD', 'addb', 'r8', 'm8'): 1,
#  ('ADD', 'addw', 'ax', 'imm16'): 1,
#  ('ADD', 'addw', 'r16', 'imm8'): 1,
#  ('ADD', 'addw', 'r16', 'imm16'): 1,
#  ('ADD', 'addw', 'r16', 'r16'): 1,
#  ('ADD', 'addw', 'r16', 'm16'): 1,
#  ('ADD', 'addl', 'eax', 'imm32'): 1,
#  ('ADD', 'addl', 'r32', 'imm8'): 1,
#  ('ADD', 'addl', 'r32', 'imm32'): 1,
#  ('ADD', 'addl', 'r32', 'r32'): 1,
#  ('ADD', 'addl', 'r32', 'm32'): 1,
#  ('ADD', 'addq', 'rax', 'imm32'): 1,
#  ('ADD', 'addq', 'r64', 'imm8'): 1,
#  ('ADD', 'addq', 'r64', 'imm32'): 1,
#  ('ADD', 'addq', 'r64', 'r64'): 1,
#  ('ADD', 'addq', 'r64', 'm64'): 1,
#  ('ADD', 'addb', 'm8', 'imm8'): 5,
#  ('ADD', 'addb', 'm8', 'r8'): 5,
#  ('ADD', 'addw', 'm16', 'imm8'): 5,
#  ('ADD', 'addw', 'm16', 'imm16'): 5,
#  ('ADD', 'addw', 'm16', 'r16'): 5,
#  ('ADD', 'addl', 'm32', 'imm8'): 5,
#  ('ADD', 'addl', 'm32', 'imm32'): 5,
#  ('ADD', 'addl', 'm32', 'r32'): 5,
#  ('ADD', 'addq', 'm64', 'imm8'): 5,
#  ('ADD', 'addq', 'm64', 'imm32'): 5,
#  ('ADD', 'addq', 'm64', 'r64'): 5,
#  ('ADDPD', 'addpd', 'xmm', 'xmm'): 1,
#  ('ADDPD', 'addpd', 'xmm', 'm128'): 1,
#  ('ADDPS', 'addps', 'xmm', 'xmm'): 6,
#  ('ADDPS', 'addps', 'xmm', 'm128'): 6,
#  ('ADDSD', 'addsd', 'xmm', 'xmm'): 1,
#  ('ADDSD', 'addsd', 'xmm', 'm64'): 1,
#  ('ADDSS', 'addss', 'xmm', 'xmm'): 4,
#  ('ADDSS', 'addss', 'xmm', 'm32'): 4,
#  ('ADDSUBPD', 'addsubpd', 'xmm', 'xmm'): 1,
#  ('ADDSUBPD', 'addsubpd', 'xmm', 'm128'): 1,
#  ('ADDSUBPS', 'addsubps', 'xmm', 'xmm'): 4,
#  ('ADDSUBPS', 'addsubps', 'xmm', 'm128'): 4,
#  ('ADOX', 'adoxl', 'r32', 'r32'): 1,
#  ('ADOX', 'adoxl', 'r32', 'm32'): 1,
#  ('ADOX', 'adoxq', 'r64', 'r64'): 1,
#  ('ADOX', 'adoxq', 'r64', 'm64'): 1,
#  ('AESDEC', 'aesdec', 'xmm', 'xmm'): 4,
#  ('AESDEC', 'aesdec', 'xmm', 'm128'): 4,
#  ('AESDECLAST', 'aesdeclast', 'xmm', 'xmm'): 4,
#  ('AESDECLAST', 'aesdeclast', 'xmm', 'm128'): 4,
#  ('AESENC', 'aesenc', 'xmm', 'xmm'): 4,
#  ('AESENC', 'aesenc', 'xmm', 'm128'): 4,
#  ('AESENCLAST', 'aesenclast', 'xmm', 'xmm'): 4,
#  ('AESENCLAST', 'aesenclast', 'xmm', 'm128'): 4,
#  ('AESIMC', 'aesimc', 'xmm', 'xmm'): 8,
#  ('AESIMC', 'aesimc', 'xmm', 'm128'): 8,
#  ('AESKEYGENASSIST', 'aeskeygenassist', 'xmm', 'xmm', 'imm8'): 12,
#  ('AESKEYGENASSIST', 'aeskeygenassist', 'xmm', 'm128', 'imm8'): 12,
#  ('AND', 'andb', 'al', 'imm8'): 1,
#  ('AND', 'andb', 'r8', 'imm8'): 1,
#  ('AND', 'andb', 'r8', 'r8'): 1,
#  ('AND', 'andb', 'r8', 'm8'): 1,
#  ('AND', 'andw', 'ax', 'imm16'): 1,
#  ('AND', 'andw', 'r16', 'imm8'): 1,
#  ('AND', 'andw', 'r16', 'imm16'): 1,
#  ('AND', 'andw', 'r16', 'r16'): 1,
#  ('AND', 'andw', 'r16', 'm16'): 1,
#  ('AND', 'andl', 'eax', 'imm32'): 1,
#  ('AND', 'andl', 'r32', 'imm8'): 1,
#  ('AND', 'andl', 'r32', 'imm32'): 1,
#  ('AND', 'andl', 'r32', 'r32'): 1,
#  ('AND', 'andl', 'r32', 'm32'): 1,
#  ('AND', 'andq', 'rax', 'imm32'): 1,
#  ('AND', 'andq', 'r64', 'imm8'): 1,
#  ('AND', 'andq', 'r64', 'imm32'): 1,
#  ('AND', 'andq', 'r64', 'r64'): 1,
#  ('AND', 'andq', 'r64', 'm64'): 1,
#  ('AND', 'andb', 'm8', 'imm8'): 5,
#  ('AND', 'andb', 'm8', 'r8'): 5,
#  ('AND', 'andw', 'm16', 'imm8'): 5,
#  ('AND', 'andw', 'm16', 'imm16'): 5,
#  ('AND', 'andw', 'm16', 'r16'): 5,
#  ('AND', 'andl', 'm32', 'imm8'): 5,
#  ('AND', 'andl', 'm32', 'imm32'): 5,
#  ('AND', 'andl', 'm32', 'r32'): 5,
#  ('AND', 'andq', 'm64', 'imm8'): 5,
#  ('AND', 'andq', 'm64', 'imm32'): 5,
#  ('AND', 'andq', 'm64', 'r64'): 5,
#  ('ANDN', 'andnl', 'r32', 'r32', 'r32'): 1,
#  ('ANDN', 'andnl', 'r32', 'r32', 'm32'): 1,
#  ('ANDN', 'andnq', 'r64', 'r64', 'r64'): 1,
#  ('ANDN', 'andnq', 'r64', 'r64', 'm64'): 1,
#  ('ANDNPD', 'andnpd', 'xmm', 'xmm'): 1,
#  ('ANDNPD', 'andnpd', 'xmm', 'm128'): 1,
#  ('ANDNPS', 'andnps', 'xmm', 'xmm'): 1,
#  ('ANDNPS', 'andnps', 'xmm', 'm128'): 1,
#  ('ANDPD', 'andpd', 'xmm', 'xmm'): 1,
#  ('ANDPD', 'andpd', 'xmm', 'm128'): 1,
#  ('ANDPS', 'andps', 'xmm', 'xmm'): 1,
#  ('ANDPS', 'andps', 'xmm', 'm128'): 1,
#  ('BEXTR', 'bextr', 'r32', 'r32', 'imm32'): 2,
#  ('BEXTR', 'bextr', 'r32', 'r32', 'r32'): 2,
#  ('BEXTR', 'bextr', 'r32', 'm32', 'imm32'): 2,
#  ('BEXTR', 'bextr', 'r32', 'm32', 'r32'): 2,
#  ('BEXTR', 'bextr', 'r64', 'r64', 'imm32'): 2,
#  ('BEXTR', 'bextr', 'r64', 'r64', 'r64'): 2,
#  ('BEXTR', 'bextr', 'r64', 'm64', 'imm32'): 2,
#  ('BEXTR', 'bextr', 'r64', 'm64', 'r64'): 2,
#  ('BLCFILL', 'blcfill', 'r32', 'r32'): 1,
#  ('BLCFILL', 'blcfill', 'r32', 'm32'): 1,
#  ('BLCFILL', 'blcfill', 'r64', 'r64'): 1,
#  ('BLCFILL', 'blcfill', 'r64', 'm64'): 1,
#  ('BLCI', 'blci', 'r32', 'r32'): 1,
#  ('BLCI', 'blci', 'r32', 'm32'): 1,
#  ('BLCI', 'blci', 'r64', 'r64'): 1,
#  ('BLCI', 'blci', 'r64', 'm64'): 1,
#  ('BLCIC', 'blcic', 'r32', 'r32'): 1,
#  ('BLCIC', 'blcic', 'r32', 'm32'): 1,
#  ('BLCIC', 'blcic', 'r64', 'r64'): 1,
#  ('BLCIC', 'blcic', 'r64', 'm64'): 1,
#  ('BLCMSK', 'blcmsk', 'r32', 'r32'): 1,
#  ('BLCMSK', 'blcmsk', 'r32', 'm32'): 1,
#  ('BLCMSK', 'blcmsk', 'r64', 'r64'): 1,
#  ('BLCMSK', 'blcmsk', 'r64', 'm64'): 1,
#  ('BLCS', 'blcs', 'r32', 'r32'): 1,
#  ('BLCS', 'blcs', 'r32', 'm32'): 1,
#  ('BLCS', 'blcs', 'r64', 'r64'): 1,
#  ('BLCS', 'blcs', 'r64', 'm64'): 1,
#  ('BLENDPD', 'blendpd', 'xmm', 'xmm', 'imm8'): 1,
#  ('BLENDPD', 'blendpd', 'xmm', 'm128', 'imm8'): 1,
#  ('BLENDPS', 'blendps', 'xmm', 'xmm', 'imm8'): 1,
#  ('BLENDPS', 'blendps', 'xmm', 'm128', 'imm8'): 1,
#  ('BLENDVPD', 'blendvpd', 'xmm', 'xmm', 'xmm0'): 1,
#  ('BLENDVPD', 'blendvpd', 'xmm', 'm128', 'xmm0'): 1,
#  ('BLENDVPS', 'blendvps', 'xmm', 'xmm', 'xmm0'): 2,
#  ('BLENDVPS', 'blendvps', 'xmm', 'm128', 'xmm0'): 1,
#  ('BLSFILL', 'blsfill', 'r32', 'r32'): 1,
#  ('BLSFILL', 'blsfill', 'r32', 'm32'): 1,
#  ('BLSFILL', 'blsfill', 'r64', 'r64'): 1,
#  ('BLSFILL', 'blsfill', 'r64', 'm64'): 1,
#  ('BLSI', 'blsi', 'r32', 'r32'): 1,
#  ('BLSI', 'blsi', 'r32', 'm32'): 1,
#  ('BLSI', 'blsi', 'r64', 'r64'): 1,
#  ('BLSI', 'blsi', 'r64', 'm64'): 1,
#  ('BLSIC', 'blsic', 'r32', 'r32'): 1,
#  ('BLSIC', 'blsic', 'r32', 'm32'): 1,
#  ('BLSIC', 'blsic', 'r64', 'r64'): 1,
#  ('BLSIC', 'blsic', 'r64', 'm64'): 1,
#  ('BLSMSK', 'blsmsk', 'r32', 'r32'): 1,
#  ('BLSMSK', 'blsmsk', 'r32', 'm32'): 1,
#  ('BLSMSK', 'blsmsk', 'r64', 'r64'): 1,
#  ('BLSMSK', 'blsmsk', 'r64', 'm64'): 1,
#  ('BLSR', 'blsr', 'r32', 'r32'): 1,
#  ('BLSR', 'blsr', 'r32', 'm32'): 1,
#  ('BLSR', 'blsr', 'r64', 'r64'): 1,
#  ('BLSR', 'blsr', 'r64', 'm64'): 1,
#  ('BSF', 'bsfw', 'r16', 'r16'): 3,
#  ('BSF', 'bsfw', 'r16', 'm16'): 3,
#  ('BSF', 'bsfl', 'r32', 'r32'): 3,
#  ('BSF', 'bsfl', 'r32', 'm32'): 3,
#  ('BSF', 'bsfq', 'r64', 'r64'): 3,
#  ('BSF', 'bsfq', 'r64', 'm64'): 3,
#  ('BSR', 'bsrw', 'r16', 'r16'): 3,
#  ('BSR', 'bsrw', 'r16', 'm16'): 3,
#  ('BSR', 'bsrl', 'r32', 'r32'): 3,
#  ('BSR', 'bsrl', 'r32', 'm32'): 3,
#  ('BSR', 'bsrq', 'r64', 'r64'): 3,
#  ('BSR', 'bsrq', 'r64', 'm64'): 3,
#  ('BSWAP', 'bswapl', 'r32'): 1,
#  ('BSWAP', 'bswapq', 'r64'): 1,
#  ('BT', 'btw', 'r16', 'imm8'): 1,
#  ('BT', 'btw', 'r16', 'r16'): 1,
#  ('BT', 'btl', 'r32', 'imm8'): 1,
#  ('BT', 'btl', 'r32', 'r32'): 1,
#  ('BT', 'btq', 'r64', 'imm8'): 1,
#  ('BT', 'btq', 'r64', 'r64'): 1,
#  ('BT', 'btw', 'm16', 'imm8'): 1,
#  ('BT', 'btw', 'm16', 'r16'): 1,
#  ('BT', 'btl', 'm32', 'imm8'): 1,
#  ('BT', 'btl', 'm32', 'r32'): 1,
#  ('BT', 'btq', 'm64', 'imm8'): 1,
#  ('BT', 'btq', 'm64', 'r64'): 1,
#  ('BTC', 'btcw', 'r16', 'imm8'): 1,
#  ('BTC', 'btcw', 'r16', 'r16'): 1,
#  ('BTC', 'btcl', 'r32', 'imm8'): 1,
#  ('BTC', 'btcl', 'r32', 'r32'): 1,
#  ('BTC', 'btcq', 'r64', 'imm8'): 1,
#  ('BTC', 'btcq', 'r64', 'r64'): 1,
#  ('BTC', 'btcw', 'm16', 'imm8'): 1,
#  ('BTC', 'btcw', 'm16', 'r16'): 1,
#  ('BTC', 'btcl', 'm32', 'imm8'): 1,
#  ('BTC', 'btcl', 'm32', 'r32'): 1,
#  ('BTC', 'btcq', 'm64', 'imm8'): 1,
#  ('BTC', 'btcq', 'm64', 'r64'): 1,
#  ('BTR', 'btrw', 'r16', 'imm8'): 1,
#  ('BTR', 'btrw', 'r16', 'r16'): 1,
#  ('BTR', 'btrl', 'r32', 'imm8'): 1,
#  ('BTR', 'btrl', 'r32', 'r32'): 1,
#  ('BTR', 'btrq', 'r64', 'imm8'): 1,
#  ('BTR', 'btrq', 'r64', 'r64'): 1,
#  ('BTR', 'btrw', 'm16', 'imm8'): 1,
#  ('BTR', 'btrw', 'm16', 'r16'): 1,
#  ('BTR', 'btrl', 'm32', 'imm8'): 1,
#  ('BTR', 'btrl', 'm32', 'r32'): 1,
#  ('BTR', 'btrq', 'm64', 'imm8'): 1,
#  ('BTR', 'btrq', 'm64', 'r64'): 1,
#  ('BTS', 'btsw', 'r16', 'imm8'): 1,
#  ('BTS', 'btsw', 'r16', 'r16'): 1,
#  ('BTS', 'btsl', 'r32', 'imm8'): 1,
#  ('BTS', 'btsl', 'r32', 'r32'): 1,
#  ('BTS', 'btsq', 'r64', 'imm8'): 1,
#  ('BTS', 'btsq', 'r64', 'r64'): 1,
#  ('BTS', 'btsw', 'm16', 'imm8'): 1,
#  ('BTS', 'btsw', 'm16', 'r16'): 1,
#  ('BTS', 'btsl', 'm32', 'imm8'): 1,
#  ('BTS', 'btsl', 'm32', 'r32'): 1,
#  ('BTS', 'btsq', 'm64', 'imm8'): 1,
#  ('BTS', 'btsq', 'm64', 'r64'): 1,
#  ('BZHI', 'bzhi', 'r32', 'r32', 'r32'): 1,
#  ('BZHI', 'bzhi', 'r32', 'm32', 'r32'): 1,
#  ('BZHI', 'bzhi', 'r64', 'r64', 'r64'): 1,
#  ('BZHI', 'bzhi', 'r64', 'm64', 'r64'): 1,
#  ('CALL', 'call', 'rel32'): 3,
#  ('CALL', 'callq', 'r64'): 3,
#  ('CALL', 'callq', 'm64'): 3,
#  ('CBW', 'cbtw'): 1,
#  ('CDQ', 'cltd'): 1,
#  ('CDQE', 'cltq'): 1,
#  ('CLC', 'clc'): 1,
#  ('CLD', 'cld'): 1,
#  ('CLFLUSH', 'clflush', 'm8'): 1,
#  ('CLFLUSHOPT', 'clflushopt', 'm8'): 1,
#  ('CLWB', 'clwb', 'm8'): 1,
#  ('CLZERO', 'clzero'): 1,
#  ('CMC', 'cmc'): 1,
#  ('CMOVA', 'cmova', 'r16', 'r16'): 1,
#  ('CMOVA', 'cmova', 'r16', 'm16'): 1,
#  ('CMOVA', 'cmova', 'r32', 'r32'): 1,
#  ('CMOVA', 'cmova', 'r32', 'm32'): 1,
#  ('CMOVA', 'cmova', 'r64', 'r64'): 1,
#  ('CMOVA', 'cmova', 'r64', 'm64'): 1,
#  ('CMOVAE', 'cmovae', 'r16', 'r16'): 1,
#  ('CMOVAE', 'cmovae', 'r16', 'm16'): 1,
#  ('CMOVAE', 'cmovae', 'r32', 'r32'): 1,
#  ('CMOVAE', 'cmovae', 'r32', 'm32'): 1,
#  ('CMOVAE', 'cmovae', 'r64', 'r64'): 1,
#  ('CMOVAE', 'cmovae', 'r64', 'm64'): 1,
#  ('CMOVB', 'cmovb', 'r16', 'r16'): 1,
#  ('CMOVB', 'cmovb', 'r16', 'm16'): 1,
#  ('CMOVB', 'cmovb', 'r32', 'r32'): 1,
#  ('CMOVB', 'cmovb', 'r32', 'm32'): 1,
#  ('CMOVB', 'cmovb', 'r64', 'r64'): 1,
#  ('CMOVB', 'cmovb', 'r64', 'm64'): 1,
#  ('CMOVBE', 'cmovbe', 'r16', 'r16'): 1,
#  ('CMOVBE', 'cmovbe', 'r16', 'm16'): 1,
#  ('CMOVBE', 'cmovbe', 'r32', 'r32'): 1,
#  ('CMOVBE', 'cmovbe', 'r32', 'm32'): 1,
#  ('CMOVBE', 'cmovbe', 'r64', 'r64'): 1,
#  ('CMOVBE', 'cmovbe', 'r64', 'm64'): 1,
#  ('CMOVC', 'cmovc', 'r16', 'r16'): 1,
#  ('CMOVC', 'cmovc', 'r16', 'm16'): 1,
#  ('CMOVC', 'cmovc', 'r32', 'r32'): 1,
#  ('CMOVC', 'cmovc', 'r32', 'm32'): 1,
#  ('CMOVC', 'cmovc', 'r64', 'r64'): 1,
#  ('CMOVC', 'cmovc', 'r64', 'm64'): 1,
#  ('CMOVE', 'cmove', 'r16', 'r16'): 1,
#  ('CMOVE', 'cmove', 'r16', 'm16'): 1,
#  ('CMOVE', 'cmove', 'r32', 'r32'): 1,
#  ('CMOVE', 'cmove', 'r32', 'm32'): 1,
#  ('CMOVE', 'cmove', 'r64', 'r64'): 1,
#  ('CMOVE', 'cmove', 'r64', 'm64'): 1,
#  ('CMOVG', 'cmovg', 'r16', 'r16'): 1,
#  ('CMOVG', 'cmovg', 'r16', 'm16'): 1,
#  ('CMOVG', 'cmovg', 'r32', 'r32'): 1,
#  ('CMOVG', 'cmovg', 'r32', 'm32'): 1,
#  ('CMOVG', 'cmovg', 'r64', 'r64'): 1,
#  ('CMOVG', 'cmovg', 'r64', 'm64'): 1,
#  ('CMOVGE', 'cmovge', 'r16', 'r16'): 1,
#  ('CMOVGE', 'cmovge', 'r16', 'm16'): 1,
#  ('CMOVGE', 'cmovge', 'r32', 'r32'): 1,
#  ('CMOVGE', 'cmovge', 'r32', 'm32'): 1,
#  ('CMOVGE', 'cmovge', 'r64', 'r64'): 1,
#  ('CMOVGE', 'cmovge', 'r64', 'm64'): 1,
#  ('CMOVL', 'cmovl', 'r16', 'r16'): 1,
#  ('CMOVL', 'cmovl', 'r16', 'm16'): 1,
#  ('CMOVL', 'cmovl', 'r32', 'r32'): 1,
#  ('CMOVL', 'cmovl', 'r32', 'm32'): 1,
#  ('CMOVL', 'cmovl', 'r64', 'r64'): 1,
#  ('CMOVL', 'cmovl', 'r64', 'm64'): 1,
#  ('CMOVLE', 'cmovle', 'r16', 'r16'): 1,
#  ('CMOVLE', 'cmovle', 'r16', 'm16'): 1,
#  ('CMOVLE', 'cmovle', 'r32', 'r32'): 1,
#  ('CMOVLE', 'cmovle', 'r32', 'm32'): 1,
#  ('CMOVLE', 'cmovle', 'r64', 'r64'): 1,
#  ('CMOVLE', 'cmovle', 'r64', 'm64'): 1,
#  ('CMOVNA', 'cmovna', 'r16', 'r16'): 1,
#  ('CMOVNA', 'cmovna', 'r16', 'm16'): 1,
#  ('CMOVNA', 'cmovna', 'r32', 'r32'): 1,
#  ('CMOVNA', 'cmovna', 'r32', 'm32'): 1,
#  ('CMOVNA', 'cmovna', 'r64', 'r64'): 1,
#  ('CMOVNA', 'cmovna', 'r64', 'm64'): 1,
#  ('CMOVNAE', 'cmovnae', 'r16', 'r16'): 1,
#  ('CMOVNAE', 'cmovnae', 'r16', 'm16'): 1,
#  ('CMOVNAE', 'cmovnae', 'r32', 'r32'): 1,
#  ('CMOVNAE', 'cmovnae', 'r32', 'm32'): 1,
#  ('CMOVNAE', 'cmovnae', 'r64', 'r64'): 1,
#  ('CMOVNAE', 'cmovnae', 'r64', 'm64'): 1,
#  ('CMOVNB', 'cmovnb', 'r16', 'r16'): 1,
#  ('CMOVNB', 'cmovnb', 'r16', 'm16'): 1,
#  ('CMOVNB', 'cmovnb', 'r32', 'r32'): 1,
#  ('CMOVNB', 'cmovnb', 'r32', 'm32'): 1,
#  ('CMOVNB', 'cmovnb', 'r64', 'r64'): 1,
#  ('CMOVNB', 'cmovnb', 'r64', 'm64'): 1,
#  ('CMOVNBE', 'cmovnbe', 'r16', 'r16'): 1,
#  ('CMOVNBE', 'cmovnbe', 'r16', 'm16'): 1,
#  ('CMOVNBE', 'cmovnbe', 'r32', 'r32'): 1,
#  ('CMOVNBE', 'cmovnbe', 'r32', 'm32'): 1,
#  ('CMOVNBE', 'cmovnbe', 'r64', 'r64'): 1,
#  ('CMOVNBE', 'cmovnbe', 'r64', 'm64'): 1,
#  ('CMOVNC', 'cmovnc', 'r16', 'r16'): 1,
#  ('CMOVNC', 'cmovnc', 'r16', 'm16'): 1,
#  ('CMOVNC', 'cmovnc', 'r32', 'r32'): 1,
#  ('CMOVNC', 'cmovnc', 'r32', 'm32'): 1,
#  ('CMOVNC', 'cmovnc', 'r64', 'r64'): 1,
#  ('CMOVNC', 'cmovnc', 'r64', 'm64'): 1,
#  ('CMOVNE', 'cmovne', 'r16', 'r16'): 1,
#  ('CMOVNE', 'cmovne', 'r16', 'm16'): 1,
#  ('CMOVNE', 'cmovne', 'r32', 'r32'): 1,
#  ('CMOVNE', 'cmovne', 'r32', 'm32'): 1,
#  ('CMOVNE', 'cmovne', 'r64', 'r64'): 1,
#  ('CMOVNE', 'cmovne', 'r64', 'm64'): 1,
#  ('CMOVNG', 'cmovng', 'r16', 'r16'): 1,
#  ('CMOVNG', 'cmovng', 'r16', 'm16'): 1,
#  ('CMOVNG', 'cmovng', 'r32', 'r32'): 1,
#  ('CMOVNG', 'cmovng', 'r32', 'm32'): 1,
#  ('CMOVNG', 'cmovng', 'r64', 'r64'): 1,
#  ('CMOVNG', 'cmovng', 'r64', 'm64'): 1,
#  ('CMOVNGE', 'cmovnge', 'r16', 'r16'): 1,
#  ('CMOVNGE', 'cmovnge', 'r16', 'm16'): 1,
#  ('CMOVNGE', 'cmovnge', 'r32', 'r32'): 1,
#  ('CMOVNGE', 'cmovnge', 'r32', 'm32'): 1,
#  ('CMOVNGE', 'cmovnge', 'r64', 'r64'): 1,
#  ('CMOVNGE', 'cmovnge', 'r64', 'm64'): 1,
#  ('CMOVNL', 'cmovnl', 'r16', 'r16'): 1,
#  ('CMOVNL', 'cmovnl', 'r16', 'm16'): 1,
#  ('CMOVNL', 'cmovnl', 'r32', 'r32'): 1,
#  ('CMOVNL', 'cmovnl', 'r32', 'm32'): 1,
#  ('CMOVNL', 'cmovnl', 'r64', 'r64'): 1,
#  ('CMOVNL', 'cmovnl', 'r64', 'm64'): 1,
#  ('CMOVNLE', 'cmovnle', 'r16', 'r16'): 1,
#  ('CMOVNLE', 'cmovnle', 'r16', 'm16'): 1,
#  ('CMOVNLE', 'cmovnle', 'r32', 'r32'): 1,
#  ('CMOVNLE', 'cmovnle', 'r32', 'm32'): 1,
#  ('CMOVNLE', 'cmovnle', 'r64', 'r64'): 1,
#  ('CMOVNLE', 'cmovnle', 'r64', 'm64'): 1,
#  ('CMOVNO', 'cmovno', 'r16', 'r16'): 1,
#  ('CMOVNO', 'cmovno', 'r16', 'm16'): 1,
#  ('CMOVNO', 'cmovno', 'r32', 'r32'): 1,
#  ('CMOVNO', 'cmovno', 'r32', 'm32'): 1,
#  ('CMOVNO', 'cmovno', 'r64', 'r64'): 1,
#  ('CMOVNO', 'cmovno', 'r64', 'm64'): 1,
#  ('CMOVNP', 'cmovnp', 'r16', 'r16'): 1,
#  ('CMOVNP', 'cmovnp', 'r16', 'm16'): 1,
#  ('CMOVNP', 'cmovnp', 'r32', 'r32'): 1,
#  ('CMOVNP', 'cmovnp', 'r32', 'm32'): 1,
#  ('CMOVNP', 'cmovnp', 'r64', 'r64'): 1,
#  ('CMOVNP', 'cmovnp', 'r64', 'm64'): 1,
#  ('CMOVNS', 'cmovns', 'r16', 'r16'): 1,
#  ('CMOVNS', 'cmovns', 'r16', 'm16'): 1,
#  ('CMOVNS', 'cmovns', 'r32', 'r32'): 1,
#  ('CMOVNS', 'cmovns', 'r32', 'm32'): 1,
#  ('CMOVNS', 'cmovns', 'r64', 'r64'): 1,
#  ('CMOVNS', 'cmovns', 'r64', 'm64'): 1,
#  ('CMOVNZ', 'cmovnz', 'r16', 'r16'): 1,
#  ('CMOVNZ', 'cmovnz', 'r16', 'm16'): 1,
#  ('CMOVNZ', 'cmovnz', 'r32', 'r32'): 1,
#  ('CMOVNZ', 'cmovnz', 'r32', 'm32'): 1,
#  ('CMOVNZ', 'cmovnz', 'r64', 'r64'): 1,
#  ('CMOVNZ', 'cmovnz', 'r64', 'm64'): 1,
#  ('CMOVO', 'cmovo', 'r16', 'r16'): 1,
#  ('CMOVO', 'cmovo', 'r16', 'm16'): 1,
#  ('CMOVO', 'cmovo', 'r32', 'r32'): 1,
#  ('CMOVO', 'cmovo', 'r32', 'm32'): 1,
#  ('CMOVO', 'cmovo', 'r64', 'r64'): 1,
#  ('CMOVO', 'cmovo', 'r64', 'm64'): 1,
#  ('CMOVP', 'cmovp', 'r16', 'r16'): 1,
#  ('CMOVP', 'cmovp', 'r16', 'm16'): 1,
#  ('CMOVP', 'cmovp', 'r32', 'r32'): 1,
#  ('CMOVP', 'cmovp', 'r32', 'm32'): 1,
#  ('CMOVP', 'cmovp', 'r64', 'r64'): 1,
#  ('CMOVP', 'cmovp', 'r64', 'm64'): 1,
#  ('CMOVPE', 'cmovpe', 'r16', 'r16'): 1,
#  ('CMOVPE', 'cmovpe', 'r16', 'm16'): 1,
#  ('CMOVPE', 'cmovpe', 'r32', 'r32'): 1,
#  ('CMOVPE', 'cmovpe', 'r32', 'm32'): 1,
#  ('CMOVPE', 'cmovpe', 'r64', 'r64'): 1,
#  ('CMOVPE', 'cmovpe', 'r64', 'm64'): 1,
#  ('CMOVPO', 'cmovpo', 'r16', 'r16'): 1,
#  ('CMOVPO', 'cmovpo', 'r16', 'm16'): 1,
#  ('CMOVPO', 'cmovpo', 'r32', 'r32'): 1,
#  ('CMOVPO', 'cmovpo', 'r32', 'm32'): 1,
#  ('CMOVPO', 'cmovpo', 'r64', 'r64'): 1,
#  ('CMOVPO', 'cmovpo', 'r64', 'm64'): 1,
#  ('CMOVS', 'cmovs', 'r16', 'r16'): 1,
#  ('CMOVS', 'cmovs', 'r16', 'm16'): 1,
#  ('CMOVS', 'cmovs', 'r32', 'r32'): 1,
#  ('CMOVS', 'cmovs', 'r32', 'm32'): 1,
#  ('CMOVS', 'cmovs', 'r64', 'r64'): 1,
#  ('CMOVS', 'cmovs', 'r64', 'm64'): 1,
#  ('CMOVZ', 'cmovz', 'r16', 'r16'): 1,
#  ('CMOVZ', 'cmovz', 'r16', 'm16'): 1,
#  ('CMOVZ', 'cmovz', 'r32', 'r32'): 1,
#  ('CMOVZ', 'cmovz', 'r32', 'm32'): 1,
#  ('CMOVZ', 'cmovz', 'r64', 'r64'): 1,
#  ('CMOVZ', 'cmovz', 'r64', 'm64'): 1,
#  ('CMP', 'cmpb', 'al', 'imm8'): 1,
#  ('CMP', 'cmpb', 'r8', 'imm8'): 1,
#  ('CMP', 'cmpb', 'r8', 'r8'): 1,
#  ('CMP', 'cmpb', 'r8', 'm8'): 1,
#  ('CMP', 'cmpw', 'ax', 'imm16'): 1,
#  ('CMP', 'cmpw', 'r16', 'imm8'): 1,
#  ('CMP', 'cmpw', 'r16', 'imm16'): 1,
#  ('CMP', 'cmpw', 'r16', 'r16'): 1,
#  ('CMP', 'cmpw', 'r16', 'm16'): 1,
#  ('CMP', 'cmpl', 'eax', 'imm32'): 1,
#  ('CMP', 'cmpl', 'r32', 'imm8'): 1,
#  ('CMP', 'cmpl', 'r32', 'imm32'): 1,
#  ('CMP', 'cmpl', 'r32', 'r32'): 1,
#  ('CMP', 'cmpl', 'r32', 'm32'): 1,
#  ('CMP', 'cmpq', 'rax', 'imm32'): 1,
#  ('CMP', 'cmpq', 'r64', 'imm8'): 1,
#  ('CMP', 'cmpq', 'r64', 'imm32'): 1,
#  ('CMP', 'cmpq', 'r64', 'r64'): 1,
#  ('CMP', 'cmpq', 'r64', 'm64'): 1,
#  ('CMP', 'cmpb', 'm8', 'imm8'): 1,
#  ('CMP', 'cmpb', 'm8', 'r8'): 1,
#  ('CMP', 'cmpw', 'm16', 'imm8'): 1,
#  ('CMP', 'cmpw', 'm16', 'imm16'): 1,
#  ('CMP', 'cmpw', 'm16', 'r16'): 1,
#  ('CMP', 'cmpl', 'm32', 'imm8'): 1,
#  ('CMP', 'cmpl', 'm32', 'imm32'): 1,
#  ('CMP', 'cmpl', 'm32', 'r32'): 1,
#  ('CMP', 'cmpq', 'm64', 'imm8'): 1,
#  ('CMP', 'cmpq', 'm64', 'imm32'): 1,
#  ('CMP', 'cmpq', 'm64', 'r64'): 1,
#  ('CMPPD', 'cmppd', 'xmm', 'xmm', 'imm8'): 1,
#  ('CMPPD', 'cmppd', 'xmm', 'm128', 'imm8'): 1,
#  ('CMPPS', 'cmpps', 'xmm', 'xmm', 'imm8'): 1,
#  ('CMPPS', 'cmpps', 'xmm', 'm128', 'imm8'): 1,
#  ('CMPSD', 'cmpsd', 'xmm', 'xmm', 'imm8'): 1,
#  ('CMPSD', 'cmpsd', 'xmm', 'm64', 'imm8'): 1,
#  ('CMPSS', 'cmpss', 'xmm', 'xmm', 'imm8'): 1,
#  ('CMPSS', 'cmpss', 'xmm', 'm32', 'imm8'): 1,
#  ('CMPXCHG', 'cmpxchgb', 'r8', 'r8'): 3,
#  ('CMPXCHG', 'cmpxchgw', 'r16', 'r16'): 3,
#  ('CMPXCHG', 'cmpxchgl', 'r32', 'r32'): 3,
#  ('CMPXCHG', 'cmpxchgq', 'r64', 'r64'): 3,
#  ('CMPXCHG', 'cmpxchgb', 'm8', 'r8'): 3,
#  ('CMPXCHG', 'cmpxchgw', 'm16', 'r16'): 3,
#  ('CMPXCHG', 'cmpxchgl', 'm32', 'r32'): 3,
#  ('CMPXCHG', 'cmpxchgq', 'm64', 'r64'): 3,
#  ('CMPXCHG16B', 'cmpxchg16b', 'm128'): 3,
#  ('CMPXCHG8B', 'cmpxchg8b', 'm64'): 3,
#  ('COMISD', 'comisd', 'xmm', 'xmm'): 1,
#  ('COMISD', 'comisd', 'xmm', 'm64'): 1,
#  ('COMISS', 'comiss', 'xmm', 'xmm'): 4,
#  ('COMISS', 'comiss', 'xmm', 'm32'): 4,
#  ('CPUID', 'cpuid'): -1,
#  ('CQO', 'cqto'): 1,
#  ('CRC32', 'crc32b', 'r32', 'r8'): 3,
#  ('CRC32', 'crc32w', 'r32', 'r16'): 3,
#  ('CRC32', 'crc32l', 'r32', 'r32'): 3,
#  ('CRC32', 'crc32b', 'r32', 'm8'): 3,
#  ('CRC32', 'crc32w', 'r32', 'm16'): 3,
#  ('CRC32', 'crc32l', 'r32', 'm32'): 3,
#  ('CRC32', 'crc32b', 'r64', 'r8'): 3,
#  ('CRC32', 'crc32q', 'r64', 'r64'): 3,
#  ('CRC32', 'crc32b', 'r64', 'm8'): 3,
#  ('CRC32', 'crc32q', 'r64', 'm64'): 3,
#  ('CVTDQ2PD', 'cvtdq2pd', 'xmm', 'xmm'): 5,
#  ('CVTDQ2PD', 'cvtdq2pd', 'xmm', 'm64'): 5,
#  ('CVTDQ2PS', 'cvtdq2ps', 'xmm', 'xmm'): 4,
#  ('CVTDQ2PS', 'cvtdq2ps', 'xmm', 'm128'): 4,
#  ('CVTPD2DQ', 'cvtpd2dq', 'xmm', 'xmm'): 1,
#  ('CVTPD2DQ', 'cvtpd2dq', 'xmm', 'm128'): 1,
#  ('CVTPD2PI', 'cvtpd2pi', 'mm', 'xmm'): 1,
#  ('CVTPD2PI', 'cvtpd2pi', 'mm', 'm128'): 1,
#  ('CVTPD2PS', 'cvtpd2ps', 'xmm', 'xmm'): 5,
#  ('CVTPD2PS', 'cvtpd2ps', 'xmm', 'm128'): 5,
#  ('CVTPI2PD', 'cvtpi2pd', 'xmm', 'mm'): 5,
#  ('CVTPI2PD', 'cvtpi2pd', 'xmm', 'm64'): 5,
#  ('CVTPI2PS', 'cvtpi2ps', 'xmm', 'mm'): 6,
#  ('CVTPI2PS', 'cvtpi2ps', 'xmm', 'm64'): 6,
#  ('CVTPS2DQ', 'cvtps2dq', 'xmm', 'xmm'): 1,
#  ('CVTPS2DQ', 'cvtps2dq', 'xmm', 'm128'): 1,
#  ('CVTPS2PD', 'cvtps2pd', 'xmm', 'xmm'): 5,
#  ('CVTPS2PD', 'cvtps2pd', 'xmm', 'm64'): 5,
#  ('CVTPS2PI', 'cvtps2pi', 'mm', 'xmm'): 1,
#  ('CVTPS2PI', 'cvtps2pi', 'mm', 'm64'): 1,
#  ('CVTSD2SI', 'cvtsd2si', 'r32', 'xmm'): 1,
#  ('CVTSD2SI', 'cvtsd2si', 'r32', 'm64'): 1,
#  ('CVTSD2SI', 'cvtsd2si', 'r64', 'xmm'): 1,
#  ('CVTSD2SI', 'cvtsd2si', 'r64', 'm64'): 1,
#  ('CVTSD2SS', 'cvtsd2ss', 'xmm', 'xmm'): 5,
#  ('CVTSD2SS', 'cvtsd2ss', 'xmm', 'm64'): 5,
#  ('CVTSI2SD', 'cvtsi2sd', 'xmm', 'r32'): 6,
#  ('CVTSI2SD', 'cvtsi2sd', 'xmm', 'r64'): 6,
#  ('CVTSI2SD', 'cvtsi2sd', 'xmm', 'm32'): 6,
#  ('CVTSI2SD', 'cvtsi2sd', 'xmm', 'm64'): 6,
#  ('CVTSI2SS', 'cvtsi2ss', 'xmm', 'r32'): 6,
#  ('CVTSI2SS', 'cvtsi2ss', 'xmm', 'r64'): 6,
#  ('CVTSI2SS', 'cvtsi2ss', 'xmm', 'm32'): 7,
#  ('CVTSI2SS', 'cvtsi2ss', 'xmm', 'm64'): 7,
#  ('CVTSS2SD', 'cvtss2sd', 'xmm', 'xmm'): 5,
#  ('CVTSS2SD', 'cvtss2sd', 'xmm', 'm32'): 5,
#  ('CVTSS2SI', 'cvtss2si', 'r32', 'xmm'): 1,
#  ('CVTSS2SI', 'cvtss2si', 'r32', 'm32'): 1,
#  ('CVTSS2SI', 'cvtss2si', 'r64', 'xmm'): 1,
#  ('CVTSS2SI', 'cvtss2si', 'r64', 'm32'): 1,
#  ('CVTTPD2DQ', 'cvttpd2dq', 'xmm', 'xmm'): 1,
#  ('CVTTPD2DQ', 'cvttpd2dq', 'xmm', 'm128'): 1,
#  ('CVTTPD2PI', 'cvttpd2pi', 'mm', 'xmm'): 1,
#  ('CVTTPD2PI', 'cvttpd2pi', 'mm', 'm128'): 1,
#  ('CVTTPS2DQ', 'cvttps2dq', 'xmm', 'xmm'): 1,
#  ('CVTTPS2DQ', 'cvttps2dq', 'xmm', 'm128'): 1,
#  ('CVTTPS2PI', 'cvttps2pi', 'mm', 'xmm'): 1,
#  ('CVTTPS2PI', 'cvttps2pi', 'mm', 'm64'): 1,
#  ('CVTTSD2SI', 'cvttsd2si', 'r32', 'xmm'): 1,
#  ('CVTTSD2SI', 'cvttsd2si', 'r32', 'm64'): 1,
#  ('CVTTSD2SI', 'cvttsd2si', 'r64', 'xmm'): 1,
#  ('CVTTSD2SI', 'cvttsd2si', 'r64', 'm64'): 1,
#  ('CVTTSS2SI', 'cvttss2si', 'r32', 'xmm'): 1,
#  ('CVTTSS2SI', 'cvttss2si', 'r32', 'm32'): 1,
#  ('CVTTSS2SI', 'cvttss2si', 'r64', 'xmm'): 1,
#  ('CVTTSS2SI', 'cvttss2si', 'r64', 'm32'): 1,
#  ('CWD', 'cwtd'): 1,
#  ('CWDE', 'cwtl'): 1,
#  ('DEC', 'decb', 'r8'): 1,
#  ('DEC', 'decw', 'r16'): 1,
#  ('DEC', 'decl', 'r32'): 1,
#  ('DEC', 'decq', 'r64'): 1,
#  ('DEC', 'decb', 'm8'): 6,
#  ('DEC', 'decw', 'm16'): 6,
#  ('DEC', 'decl', 'm32'): 6,
#  ('DEC', 'decq', 'm64'): 6,
#  ('DIV', 'divb', 'r8'): 23,
#  ('DIV', 'divw', 'r16'): 23,
#  ('DIV', 'divl', 'r32'): 23,
#  ('DIV', 'divq', 'r64'): 23,
#  ('DIV', 'divb', 'm8'): 3,
#  ('DIV', 'divw', 'm16'): 3,
#  ('DIV', 'divl', 'm32'): 3,
#  ('DIV', 'divq', 'm64'): 3,
#  ('DIVPD', 'divpd', 'xmm', 'xmm'): 14,
#  ('DIVPD', 'divpd', 'xmm', 'm128'): 14,
#  ('DIVPS', 'divps', 'xmm', 'xmm'): 11,
#  ('DIVPS', 'divps', 'xmm', 'm128'): 11,
#  ('DIVSD', 'divsd', 'xmm', 'xmm'): 14,
#  ('DIVSD', 'divsd', 'xmm', 'm64'): 14,
#  ('DIVSS', 'divss', 'xmm', 'xmm'): 11,
#  ('DIVSS', 'divss', 'xmm', 'm32'): 11,
#  ('DPPD', 'dppd', 'xmm', 'xmm', 'imm8'): 9,
#  ('DPPD', 'dppd', 'xmm', 'm128', 'imm8'): 9,
#  ('DPPS', 'dpps', 'xmm', 'xmm', 'imm8'): 13,
#  ('DPPS', 'dpps', 'xmm', 'm128', 'imm8'): 13,
#  ('EMMS', 'emms'): 12,
#  ('EXTRACTPS', 'extractps', 'r32', 'xmm', 'imm8'): 1,
#  ('EXTRACTPS', 'extractps', 'm32', 'xmm', 'imm8'): 5,
#  ('EXTRQ', 'extrq', 'xmm', 'xmm'): 1,
#  ('EXTRQ', 'extrq', 'xmm', 'imm8', 'imm8'): 1,
#  ('FEMMS', 'femms'): 1,
#  ('HADDPD', 'haddpd', 'xmm', 'xmm'): 1,
#  ('HADDPD', 'haddpd', 'xmm', 'm128'): 1,
#  ('HADDPS', 'haddps', 'xmm', 'xmm'): 6,
#  ('HADDPS', 'haddps', 'xmm', 'm128'): 6,
#  ('HSUBPD', 'hsubpd', 'xmm', 'xmm'): 1,
#  ('HSUBPD', 'hsubpd', 'xmm', 'm128'): 1,
#  ('HSUBPS', 'hsubps', 'xmm', 'xmm'): 6,
#  ('HSUBPS', 'hsubps', 'xmm', 'm128'): 6,
#  ('IDIV', 'idivb', 'r8'): 24,
#  ('IDIV', 'idivw', 'r16'): 24,
#  ('IDIV', 'idivl', 'r32'): 24,
#  ('IDIV', 'idivq', 'r64'): 24,
#  ('IDIV', 'idivb', 'm8'): 3,
#  ('IDIV', 'idivw', 'm16'): 3,
#  ('IDIV', 'idivl', 'm32'): 3,
#  ('IDIV', 'idivq', 'm64'): 3,
#  ('IMUL', 'imulb', 'r8'): 3,
#  ('IMUL', 'imulw', 'r16'): 3,
#  ('IMUL', 'imull', 'r32'): 3,
#  ('IMUL', 'imulq', 'r64'): 3,
#  ('IMUL', 'imulb', 'm8'): 3,
#  ('IMUL', 'imulw', 'm16'): 3,
#  ('IMUL', 'imull', 'm32'): 3,
#  ('IMUL', 'imulq', 'm64'): 3,
#  ('IMUL', 'imulw', 'r16', 'r16'): 3,
#  ('IMUL', 'imulw', 'r16', 'm16'): 3,
#  ('IMUL', 'imull', 'r32', 'r32'): 3,
#  ('IMUL', 'imull', 'r32', 'm32'): 3,
#  ('IMUL', 'imulq', 'r64', 'r64'): 3,
#  ('IMUL', 'imulq', 'r64', 'm64'): 3,
#  ('IMUL', 'imulw', 'r16', 'r16', 'imm8'): 4,
#  ('IMUL', 'imulw', 'r16', 'r16', 'imm16'): 4,
#  ('IMUL', 'imulw', 'r16', 'm16', 'imm8'): 3,
#  ('IMUL', 'imulw', 'r16', 'm16', 'imm16'): 3,
#  ('IMUL', 'imull', 'r32', 'r32', 'imm8'): 4,
#  ('IMUL', 'imull', 'r32', 'r32', 'imm32'): 4,
#  ('IMUL', 'imull', 'r32', 'm32', 'imm8'): 3,
#  ('IMUL', 'imull', 'r32', 'm32', 'imm32'): 3,
#  ('IMUL', 'imulq', 'r64', 'r64', 'imm8'): 4,
#  ('IMUL', 'imulq', 'r64', 'r64', 'imm32'): 4,
#  ('IMUL', 'imulq', 'r64', 'm64', 'imm8'): 3,
#  ('IMUL', 'imulq', 'r64', 'm64', 'imm32'): 3,
#  ('INC', 'incb', 'r8'): 1,
#  ('INC', 'incw', 'r16'): 1,
#  ('INC', 'incl', 'r32'): 1,
#  ('INC', 'incq', 'r64'): 1,
#  ('INC', 'incb', 'm8'): 6,
#  ('INC', 'incw', 'm16'): 6,
#  ('INC', 'incl', 'm32'): 6,
#  ('INC', 'incq', 'm64'): 6,
#  ('INSERTPS', 'insertps', 'xmm', 'xmm', 'imm8'): 1,
#  ('INSERTPS', 'insertps', 'xmm', 'm32', 'imm8'): 4,
#  ('INSERTQ', 'insertq', 'xmm', 'xmm'): 1,
#  ('INSERTQ', 'insertq', 'xmm', 'xmm', 'imm8', 'imm8'): 1,
#  ('INT', 'int', '3'): 3,
#  ('INT', 'int', 'imm8'): 3,
#  ('JA', 'ja', 'rel8'): 1,
#  ('JA', 'ja', 'rel32'): 1,
#  ('JAE', 'jae', 'rel8'): 1,
#  ('JAE', 'jae', 'rel32'): 1,
#  ('JB', 'jb', 'rel8'): 1,
#  ('JB', 'jb', 'rel32'): 1,
#  ('JBE', 'jbe', 'rel8'): 1,
#  ('JBE', 'jbe', 'rel32'): 1,
#  ('JC', 'jc', 'rel8'): 1,
#  ('JC', 'jc', 'rel32'): 1,
#  ('JE', 'je', 'rel8'): 1,
#  ('JE', 'je', 'rel32'): 1,
#  ('JECXZ', 'jecxz', 'rel8'): 1,
#  ('JG', 'jg', 'rel8'): 1,
#  ('JG', 'jg', 'rel32'): 1,
#  ('JGE', 'jge', 'rel8'): 1,
#  ('JGE', 'jge', 'rel32'): 1,
#  ('JL', 'jl', 'rel8'): 1,
#  ('JL', 'jl', 'rel32'): 1,
#  ('JLE', 'jle', 'rel8'): 1,
#  ('JLE', 'jle', 'rel32'): 1,
#  ('JMP', 'jmp', 'rel8'): 3,
#  ('JMP', 'jmp', 'rel32'): 3,
#  ('JMP', 'jmpq', 'r64'): 3,
#  ('JMP', 'jmpq', 'm64'): 3,
#  ('JNA', 'jna', 'rel8'): 1,
#  ('JNA', 'jna', 'rel32'): 1,
#  ('JNAE', 'jnae', 'rel8'): 1,
#  ('JNAE', 'jnae', 'rel32'): 1,
#  ('JNB', 'jnb', 'rel8'): 1,
#  ('JNB', 'jnb', 'rel32'): 1,
#  ('JNBE', 'jnbe', 'rel8'): 1,
#  ('JNBE', 'jnbe', 'rel32'): 1,
#  ('JNC', 'jnc', 'rel8'): 1,
#  ('JNC', 'jnc', 'rel32'): 1,
#  ('JNE', 'jne', 'rel8'): 1,
#  ('JNE', 'jne', 'rel32'): 1,
#  ('JNG', 'jng', 'rel8'): 1,
#  ('JNG', 'jng', 'rel32'): 1,
#  ('JNGE', 'jnge', 'rel8'): 1,
#  ('JNGE', 'jnge', 'rel32'): 1,
#  ('JNL', 'jnl', 'rel8'): 1,
#  ('JNL', 'jnl', 'rel32'): 1,
#  ('JNLE', 'jnle', 'rel8'): 1,
#  ('JNLE', 'jnle', 'rel32'): 1,
#  ('JNO', 'jno', 'rel8'): 1,
#  ('JNO', 'jno', 'rel32'): 1,
#  ('JNP', 'jnp', 'rel8'): 1,
#  ('JNP', 'jnp', 'rel32'): 1,
#  ('JNS', 'jns', 'rel8'): 1,
#  ('JNS', 'jns', 'rel32'): 1,
#  ('JNZ', 'jnz', 'rel8'): 1,
#  ('JNZ', 'jnz', 'rel32'): 1,
#  ('JO', 'jo', 'rel8'): 1,
#  ('JO', 'jo', 'rel32'): 1,
#  ('JP', 'jp', 'rel8'): 1,
#  ('JP', 'jp', 'rel32'): 1,
#  ('JPE', 'jpe', 'rel8'): 1,
#  ('JPE', 'jpe', 'rel32'): 1,
#  ('JPO', 'jpo', 'rel8'): 1,
#  ('JPO', 'jpo', 'rel32'): 1,
#  ('JRCXZ', 'jrcxz', 'rel8'): 1,
#  ('JS', 'js', 'rel8'): 1,
#  ('JS', 'js', 'rel32'): 1,
#  ('JZ', 'jz', 'rel8'): 1,
#  ('JZ', 'jz', 'rel32'): 1,
#  ('KADDB', 'kaddb', 'k', 'k', 'k'): 1,
#  ('KADDD', 'kaddd', 'k', 'k', 'k'): 1,
#  ('KADDQ', 'kaddq', 'k', 'k', 'k'): 1,
#  ('KADDW', 'kaddw', 'k', 'k', 'k'): 1,
#  ('KANDB', 'kandb', 'k', 'k', 'k'): 1,
#  ('KANDD', 'kandd', 'k', 'k', 'k'): 1,
#  ('KANDNB', 'kandnb', 'k', 'k', 'k'): 1,
#  ('KANDND', 'kandnd', 'k', 'k', 'k'): 1,
#  ('KANDNQ', 'kandnq', 'k', 'k', 'k'): 1,
#  ('KANDNW', 'kandnw', 'k', 'k', 'k'): 1,
#  ('KANDQ', 'kandq', 'k', 'k', 'k'): 1,
#  ('KANDW', 'kandw', 'k', 'k', 'k'): 1,
#  ('KMOVB', 'kmovb', 'k', 'k'): 1,
#  ('KMOVB', 'kmovb', 'k', 'r32'): 1,
#  ('KMOVB', 'kmovb', 'k', 'm8'): 1,
#  ('KMOVB', 'kmovb', 'r32', 'k'): 1,
#  ('KMOVB', 'kmovb', 'm8', 'k'): 1,
#  ('KMOVD', 'kmovd', 'k', 'k'): 500,
#  ('KMOVD', 'kmovd', 'k', 'r32'): 500,
#  ('KMOVD', 'kmovd', 'k', 'm32'): 500,
#  ('KMOVD', 'kmovd', 'r32', 'k'): 500,
#  ('KMOVD', 'kmovd', 'm32', 'k'): 14,
#  ('KMOVQ', 'kmovq', 'k', 'k'): 450,
#  ('KMOVQ', 'kmovq', 'k', 'r64'): 450,
#  ('KMOVQ', 'kmovq', 'k', 'm64'): 450,
#  ('KMOVQ', 'kmovq', 'r64', 'k'): 450,
#  ('KMOVQ', 'kmovq', 'm64', 'k'): 450,
#  ('KMOVW', 'kmovw', 'k', 'k'): 1,
#  ('KMOVW', 'kmovw', 'k', 'r32'): 1,
#  ('KMOVW', 'kmovw', 'k', 'm16'): 1,
#  ('KMOVW', 'kmovw', 'r32', 'k'): 1,
#  ('KMOVW', 'kmovw', 'm16', 'k'): 1,
#  ('KNOTB', 'knotb', 'k', 'k'): 1,
#  ('KNOTD', 'knotd', 'k', 'k'): 1,
#  ('KNOTQ', 'knotq', 'k', 'k'): 1,
#  ('KNOTW', 'knotw', 'k', 'k'): 1,
#  ('KORB', 'korb', 'k', 'k', 'k'): 1,
#  ('KORD', 'kord', 'k', 'k', 'k'): 1,
#  ('KORQ', 'korq', 'k', 'k', 'k'): 1,
#  ('KORTESTB', 'kortestb', 'k', 'k'): 1,
#  ('KORTESTD', 'kortestd', 'k', 'k'): 1,
#  ('KORTESTQ', 'kortestq', 'k', 'k'): 1,
#  ('KORTESTW', 'kortestw', 'k', 'k'): 1,
#  ('KORW', 'korw', 'k', 'k', 'k'): 1,
#  ('KSHIFTLB', 'kshiftlb', 'k', 'k', 'imm8'): 1,
#  ('KSHIFTLD', 'kshiftld', 'k', 'k', 'imm8'): 1,
#  ('KSHIFTLQ', 'kshiftlq', 'k', 'k', 'imm8'): 1,
#  ('KSHIFTLW', 'kshiftlw', 'k', 'k', 'imm8'): 1,
#  ('KSHIFTRB', 'kshiftrb', 'k', 'k', 'imm8'): 1,
#  ('KSHIFTRD', 'kshiftrd', 'k', 'k', 'imm8'): 1,
#  ('KSHIFTRQ', 'kshiftrq', 'k', 'k', 'imm8'): 1,
#  ('KSHIFTRW', 'kshiftrw', 'k', 'k', 'imm8'): 1,
#  ('KTESTB', 'ktestb', 'k', 'k'): 1,
#  ('KTESTD', 'ktestd', 'k', 'k'): 1,
#  ('KTESTQ', 'ktestq', 'k', 'k'): 1,
#  ('KTESTW', 'ktestw', 'k', 'k'): 1,
#  ('KUNPCKBW', 'kunpckbw', 'k', 'k', 'k'): 1,
#  ('KUNPCKDQ', 'kunpckdq', 'k', 'k', 'k'): 1,
#  ('KUNPCKWD', 'kunpckwd', 'k', 'k', 'k'): 1,
#  ('KXNORB', 'kxnorb', 'k', 'k', 'k'): 1,
#  ('KXNORD', 'kxnord', 'k', 'k', 'k'): 1,
#  ('KXNORQ', 'kxnorq', 'k', 'k', 'k'): 1,
#  ('KXNORW', 'kxnorw', 'k', 'k', 'k'): 1,
#  ('KXORB', 'kxorb', 'k', 'k', 'k'): 1,
#  ('KXORD', 'kxord', 'k', 'k', 'k'): 1,
#  ('KXORQ', 'kxorq', 'k', 'k', 'k'): 1,
#  ('KXORW', 'kxorw', 'k', 'k', 'k'): 1,
#  ('LDDQU', 'lddqu', 'xmm', 'm128'): 3,
#  ('LDMXCSR', 'ldmxcsr', 'm32'): 5,
#  ('LEA', 'leaw', 'r16', 'm'): 4,
#  ('LEA', 'leal', 'r32', 'm'): 4,
#  ('LEA', 'leaq', 'r64', 'm'): 4,
#  ('LFENCE', 'lfence'): 2,
#  ('LZCNT', 'lzcntw', 'r16', 'r16'): 3,
#  ('LZCNT', 'lzcntw', 'r16', 'm16'): 3,
#  ('LZCNT', 'lzcntl', 'r32', 'r32'): 3,
#  ('LZCNT', 'lzcntl', 'r32', 'm32'): 3,
#  ('LZCNT', 'lzcntq', 'r64', 'r64'): 3,
#  ('LZCNT', 'lzcntq', 'r64', 'm64'): 3,
#  ('MASKMOVDQU', 'maskmovdqu', 'xmm', 'xmm'): 500,
#  ('MASKMOVQ', 'maskmovq', 'mm', 'mm'): 450,
#  ('MAXPD', 'maxpd', 'xmm', 'xmm'): 1,
#  ('MAXPD', 'maxpd', 'xmm', 'm128'): 1,
#  ('MAXPS', 'maxps', 'xmm', 'xmm'): 1,
#  ('MAXPS', 'maxps', 'xmm', 'm128'): 1,
#  ('MAXSD', 'maxsd', 'xmm', 'xmm'): 1,
#  ('MAXSD', 'maxsd', 'xmm', 'm64'): 1,
#  ('MAXSS', 'maxss', 'xmm', 'xmm'): 4,
#  ('MAXSS', 'maxss', 'xmm', 'm32'): 4,
#  ('MFENCE', 'mfence'): 2,
#  ('MINPD', 'minpd', 'xmm', 'xmm'): 1,
#  ('MINPD', 'minpd', 'xmm', 'm128'): 1,
#  ('MINPS', 'minps', 'xmm', 'xmm'): 1,
#  ('MINPS', 'minps', 'xmm', 'm128'): 1,
#  ('MINSD', 'minsd', 'xmm', 'xmm'): 1,
#  ('MINSD', 'minsd', 'xmm', 'm64'): 1,
#  ('MINSS', 'minss', 'xmm', 'xmm'): 4,
#  ('MINSS', 'minss', 'xmm', 'm32'): 4,
#  ('MONITOR', 'monitor'): 1,
#  ('MONITORX', 'monitorx'): 1,
#  ('MOV', 'movb', 'r8', 'imm8'): 1,
#  ('MOV', 'movb', 'r8', 'r8'): 1,
#  ('MOV', 'movb', 'r8', 'm8'): 1,
#  ('MOV', 'movw', 'r16', 'imm16'): 1,
#  ('MOV', 'movw', 'r16', 'r16'): 1,
#  ('MOV', 'movw', 'r16', 'm16'): 1,
#  ('MOV', 'movabs', 'eax', 'moffs32'): 1,
#  ('MOV', 'movl', 'r32', 'imm32'): 1,
#  ('MOV', 'movl', 'r32', 'r32'): 1,
#  ('MOV', 'movl', 'r32', 'm32'): 1,
#  ('MOV', 'movabs', 'rax', 'moffs64'): 1,
#  ('MOV', 'movq', 'r64', 'imm32'): 1,
#  ('MOV', 'movq', 'r64', 'imm64'): 1,
#  ('MOV', 'movq', 'r64', 'r64'): 1,
#  ('MOV', 'movq', 'r64', 'm64'): 1,
#  ('MOV', 'movb', 'm8', 'imm8'): 2,
#  ('MOV', 'movb', 'm8', 'r8'): 2,
#  ('MOV', 'movw', 'm16', 'imm16'): 2,
#  ('MOV', 'movw', 'm16', 'r16'): 2,
#  ('MOV', 'movl', 'm32', 'imm32'): 2,
#  ('MOV', 'movl', 'm32', 'r32'): 2,
#  ('MOV', 'movq', 'm64', 'imm32'): 2,
#  ('MOV', 'movq', 'm64', 'r64'): 2,
#  ('MOV', 'movabs', 'moffs32', 'eax'): 1,
#  ('MOV', 'movabs', 'moffs64', 'rax'): 1,
#  ('MOVAPD', 'movapd', 'xmm', 'xmm'): 1,
#  ('MOVAPD', 'movapd', 'xmm', 'm128'): 1,
#  ('MOVAPD', 'movapd', 'm128', 'xmm'): 1,
#  ('MOVAPS', 'movaps', 'xmm', 'xmm'): 1,
#  ('MOVAPS', 'movaps', 'xmm', 'm128'): 3,
#  ('MOVAPS', 'movaps', 'm128', 'xmm'): 3,
#  ('MOVBE', 'movbew', 'r16', 'm16'): 2,
#  ('MOVBE', 'movbel', 'r32', 'm32'): 2,
#  ('MOVBE', 'movbeq', 'r64', 'm64'): 2,
#  ('MOVBE', 'movbew', 'm16', 'r16'): 2,
#  ('MOVBE', 'movbel', 'm32', 'r32'): 2,
#  ('MOVBE', 'movbeq', 'm64', 'r64'): 2,
#  ('MOVD', 'movd', 'r32', 'mm'): 2,
#  ('MOVD', 'movd', 'r32', 'xmm'): 2,
#  ('MOVD', 'movd', 'mm', 'r32'): 2,
#  ('MOVD', 'movd', 'mm', 'm32'): 2,
#  ('MOVD', 'movd', 'xmm', 'r32'): 2,
#  ('MOVD', 'movd', 'xmm', 'm32'): 2,
#  ('MOVD', 'movd', 'm32', 'mm'): 3,
#  ('MOVD', 'movd', 'm32', 'xmm'): 3,
#  ('MOVDDUP', 'movddup', 'xmm', 'xmm'): 1,
#  ('MOVDDUP', 'movddup', 'xmm', 'm64'): 3,
#  ('MOVDQ2Q', 'movdq2q', 'mm', 'xmm'): 2,
#  ('MOVDQA', 'movdqa', 'xmm', 'xmm'): 1,
#  ('MOVDQA', 'movdqa', 'xmm', 'm128'): 2,
#  ('MOVDQA', 'movdqa', 'm128', 'xmm'): 3,
#  ('MOVDQU', 'movdqu', 'xmm', 'xmm'): 500,
#  ('MOVDQU', 'movdqu', 'xmm', 'm128'): 500,
#  ('MOVDQU', 'movdqu', 'm128', 'xmm'): 500,
#  ('MOVHLPS', 'movhlps', 'xmm', 'xmm'): 1,
#  ('MOVHPD', 'movhpd', 'xmm', 'm64'): 1,
#  ('MOVHPD', 'movhpd', 'm64', 'xmm'): 1,
#  ('MOVHPS', 'movhps', 'xmm', 'm64'): 4,
#  ('MOVHPS', 'movhps', 'm64', 'xmm'): 3,
#  ('MOVLHPS', 'movlhps', 'xmm', 'xmm'): 1,
#  ('MOVLPD', 'movlpd', 'xmm', 'm64'): 1,
#  ('MOVLPD', 'movlpd', 'm64', 'xmm'): 1,
#  ('MOVLPS', 'movlps', 'xmm', 'm64'): 4,
#  ('MOVLPS', 'movlps', 'm64', 'xmm'): 3,
#  ('MOVMSKPD', 'movmskpd', 'r32', 'xmm'): 1,
#  ('MOVMSKPS', 'movmskps', 'r32', 'xmm'): 2,
#  ('MOVNTDQ', 'movntdq', 'm128', 'xmm'): 450,
#  ('MOVNTDQA', 'movntdqa', 'xmm', 'm128'): 3,
#  ('MOVNTI', 'movntil', 'm32', 'r32'): 400,
#  ('MOVNTI', 'movntiq', 'm64', 'r64'): 400,
#  ('MOVNTPD', 'movntpd', 'm128', 'xmm'): 1,
#  ('MOVNTPS', 'movntps', 'm128', 'xmm'): 400,
#  ('MOVNTQ', 'movntq', 'm64', 'mm'): 418,
#  ('MOVNTSD', 'movntsd', 'm64', 'xmm'): 1,
#  ('MOVNTSS', 'movntss', 'm32', 'xmm'): 1,
#  ('MOVQ', 'movq', 'r64', 'mm'): 2,
#  ('MOVQ', 'movq', 'r64', 'xmm'): 2,
#  ('MOVQ', 'movq', 'mm', 'r64'): 2,
#  ('MOVQ', 'movq', 'mm', 'mm'): 2,
#  ('MOVQ', 'movq', 'mm', 'm64'): 2,
#  ('MOVQ', 'movq', 'xmm', 'r64'): 2,
#  ('MOVQ', 'movq', 'xmm', 'xmm'): 2,
#  ('MOVQ', 'movq', 'xmm', 'm64'): 2,
#  ('MOVQ', 'movq', 'm64', 'mm'): 3,
#  ('MOVQ', 'movq', 'm64', 'xmm'): 3,
#  ('MOVQ2DQ', 'movq2dq', 'xmm', 'mm'): 2,
#  ('MOVSD', 'movsd', 'xmm', 'xmm'): 1,
#  ('MOVSD', 'movsd', 'xmm', 'm64'): 1,
#  ('MOVSD', 'movsd', 'm64', 'xmm'): 1,
#  ('MOVSHDUP', 'movshdup', 'xmm', 'xmm'): 1,
#  ('MOVSHDUP', 'movshdup', 'xmm', 'm128'): 1,
#  ('MOVSLDUP', 'movsldup', 'xmm', 'xmm'): 1,
#  ('MOVSLDUP', 'movsldup', 'xmm', 'm128'): 1,
#  ('MOVSS', 'movss', 'xmm', 'xmm'): 1,
#  ('MOVSS', 'movss', 'xmm', 'm32'): 3,
#  ('MOVSS', 'movss', 'm32', 'xmm'): 3,
#  ('MOVSX', 'movsbw', 'r16', 'r8'): 1,
#  ('MOVSX', 'movsbw', 'r16', 'm8'): 1,
#  ('MOVSX', 'movsbl', 'r32', 'r8'): 1,
#  ('MOVSX', 'movswl', 'r32', 'r16'): 1,
#  ('MOVSX', 'movsbl', 'r32', 'm8'): 1,
#  ('MOVSX', 'movswl', 'r32', 'm16'): 1,
#  ('MOVSX', 'movsbq', 'r64', 'r8'): 1,
#  ('MOVSX', 'movswq', 'r64', 'r16'): 1,
#  ('MOVSX', 'movsbq', 'r64', 'm8'): 1,
#  ('MOVSX', 'movswq', 'r64', 'm16'): 1,
#  ('MOVSXD', 'movslq', 'r64', 'r32'): 1,
#  ('MOVSXD', 'movslq', 'r64', 'm32'): 1,
#  ('MOVUPD', 'movupd', 'xmm', 'xmm'): 1,
#  ('MOVUPD', 'movupd', 'xmm', 'm128'): 1,
#  ('MOVUPD', 'movupd', 'm128', 'xmm'): 1,
#  ('MOVUPS', 'movups', 'xmm', 'xmm'): 3,
#  ('MOVUPS', 'movups', 'xmm', 'm128'): 3,
#  ('MOVUPS', 'movups', 'm128', 'xmm'): 3,
#  ('MOVZX', 'movzbw', 'r16', 'r8'): 1,
#  ('MOVZX', 'movzbw', 'r16', 'm8'): 1,
#  ('MOVZX', 'movzbl', 'r32', 'r8'): 1,
#  ('MOVZX', 'movzwl', 'r32', 'r16'): 1,
#  ('MOVZX', 'movzbl', 'r32', 'm8'): 1,
#  ('MOVZX', 'movzwl', 'r32', 'm16'): 1,
#  ('MOVZX', 'movzbq', 'r64', 'r8'): 1,
#  ('MOVZX', 'movzwq', 'r64', 'r16'): 1,
#  ('MOVZX', 'movzbq', 'r64', 'm8'): 1,
#  ('MOVZX', 'movzwq', 'r64', 'm16'): 1,
#  ('MPSADBW', 'mpsadbw', 'xmm', 'xmm', 'imm8'): 4,
#  ('MPSADBW', 'mpsadbw', 'xmm', 'm128', 'imm8'): 4,
#  ('MUL', 'mulb', 'r8'): 3,
#  ('MUL', 'mulw', 'r16'): 3,
#  ('MUL', 'mull', 'r32'): 3,
#  ('MUL', 'mulq', 'r64'): 3,
#  ('MUL', 'mulb', 'm8'): 3,
#  ('MUL', 'mulw', 'm16'): 3,
#  ('MUL', 'mull', 'm32'): 3,
#  ('MUL', 'mulq', 'm64'): 3,
#  ('MULPD', 'mulpd', 'xmm', 'xmm'): 1,
#  ('MULPD', 'mulpd', 'xmm', 'm128'): 1,
#  ('MULPS', 'mulps', 'xmm', 'xmm'): 1,
#  ('MULPS', 'mulps', 'xmm', 'm128'): 1,
#  ('MULSD', 'mulsd', 'xmm', 'xmm'): 1,
#  ('MULSD', 'mulsd', 'xmm', 'm64'): 1,
#  ('MULSS', 'mulss', 'xmm', 'xmm'): 4,
#  ('MULSS', 'mulss', 'xmm', 'm32'): 4,
#  ('MULX', 'mulxl', 'r32', 'r32', 'r32'): 4,
#  ('MULX', 'mulxl', 'r32', 'r32', 'm32'): 4,
#  ('MULX', 'mulxq', 'r64', 'r64', 'r64'): 4,
#  ('MULX', 'mulxq', 'r64', 'r64', 'm64'): 4,
#  ('MWAIT', 'mwait'): 1,
#  ('MWAITX', 'mwaitx'): 1,
#  ('NEG', 'negb', 'r8'): 1,
#  ('NEG', 'negw', 'r16'): 1,
#  ('NEG', 'negl', 'r32'): 1,
#  ('NEG', 'negq', 'r64'): 1,
#  ('NEG', 'negb', 'm8'): 6,
#  ('NEG', 'negw', 'm16'): 6,
#  ('NEG', 'negl', 'm32'): 6,
#  ('NEG', 'negq', 'm64'): 6,
#  ('NOP', 'nop'): 3,
#  ('NOT', 'notb', 'r8'): 1,
#  ('NOT', 'notw', 'r16'): 1,
#  ('NOT', 'notl', 'r32'): 1,
#  ('NOT', 'notq', 'r64'): 1,
#  ('NOT', 'notb', 'm8'): 6,
#  ('NOT', 'notw', 'm16'): 6,
#  ('NOT', 'notl', 'm32'): 6,
#  ('NOT', 'notq', 'm64'): 6,
#  ('OR', 'orb', 'al', 'imm8'): 1,
#  ('OR', 'orb', 'r8', 'imm8'): 1,
#  ('OR', 'orb', 'r8', 'r8'): 1,
#  ('OR', 'orb', 'r8', 'm8'): 1,
#  ('OR', 'orw', 'ax', 'imm16'): 1,
#  ('OR', 'orw', 'r16', 'imm8'): 1,
#  ('OR', 'orw', 'r16', 'imm16'): 1,
#  ('OR', 'orw', 'r16', 'r16'): 1,
#  ...}
