# %%
# %load_ext autoreload
# %autoreload 2
# !pwd
import os
import sys 
if os.path.abspath("../../../") not in sys.path:
    sys.path.append(os.path.abspath("../../../"))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /home/gilles/git-repos/NemesisRetroWrite/retrowrite/rwtools/nemesis/notebooks

# %%
# %autoreload 2
import os
import networkx as nx
from rwtools.nemesis.graph.nemesis_node import AbstractNemesisNode
import matplotlib.pyplot as plt
import os
import matplotlib.image as mpimg
from rwtools.nemesis.control_flow_graph import ControlFlowGraph

from rwtools.nemesis.graph.utils import to_img 

G = nx.DiGraph()
n1 = AbstractNemesisNode([2], "n1")
n2 = AbstractNemesisNode([3], "n2")

G.add_node(n1)
G.add_node(n2)

G.add_edge(n1, n2)

figs, axs = plt.subplots(1, 2, figsize=(10, 10))

axs[0].imshow(to_img(G))
cfg = ControlFlowGraph(list(G.nodes), G)

cfg.merge_consecutive_nodes()

axs[1].imshow(to_img(G))

merged_node = list(G.nodes)[0]
merged_node
merged_node.num_instructions()

# sum(merged_node.latencies)
sum(sum(lats) for lats in merged_node.latencies)
# Out:
# 5
